# %%
# ===================================================================
# PASO 1: CONFIGURACIÓN E INSTALACIÓN DE LIBRERÍAS
# ===================================================================

import pandas as pd
import requests
import sqlite3

print("✅ Librerías importadas.")

# ===================================================================
# PASO 2: EXTRACCIÓN (EXTRACT) DE LOS DATOS
# ===================================================================

# La plataforma datos.gov.co usa la API de Socrata. Podemos usarla para
# descargar los datos directamente, lo que es más eficiente que bajar un CSV.
# Aumentamos el límite para traer más filas (ajusta si es necesario).
api_url = "https://www.datos.gov.co/resource/nudc-7mev.json?$limit=50000"

print(f"📥 Extrayendo datos desde: {api_url}")

try:
    response = requests.get(api_url)
    response.raise_for_status()  # Lanza un error si la petición falla (ej: 404)
    data = response.json()
    df_raw = pd.DataFrame(data)
    print(f"✅ ¡Extracción exitosa! Se cargaron {len(df_raw)} filas.")
    display(df_raw.head())

except requests.exceptions.RequestException as e:
    print(f"❌ Error al extraer los datos: {e}")
    df_raw = pd.DataFrame() # Creamos un dataframe vacío para evitar errores posteriores

except Exception as e:
    print(f"❌ Ocurrió un error inesperado: {e}")
    df_raw = pd.DataFrame()
# Out:
# ✅ Librerías importadas.
# 📥 Extrayendo datos desde: https://www.datos.gov.co/resource/nudc-7mev.json?$limit=50000
# ✅ ¡Extracción exitosa! Se cargaron 14585 filas.
#     a_o c_digo_municipio   municipio c_digo_departamento departamento  \
# 0  2023            05004    Abriaquí                  05    Antioquia
# 1  2023            95025  El Retorno                  95     Guaviare
# 2  2023            95200  Miraflores                  95     Guaviare
# 3  2023            97001        Mitú                  97       Vaupés
# 4  2023            97161      Caruru                  97       Vaupés
#
#   c_digo_etc              etc poblaci_n_5_16 tasa_matriculaci_n_5_16  \
# 0       3758  Antioquia (ETC)            503                   62.62
# 1       3830   Guaviare (ETC)           4438                   53.27
# 2       3830   Guaviare (ETC)           2014                   32.52
# 3       3831     Vaupés (ETC)          10986                   59.57
# 4       3831     Vaupés (ETC)           1228                    51.3
#
#   cobertura_neta  ... reprobaci_n_primaria reprobaci_n_secundaria  \
# 0          62.62  ...                 1.96                  16.51
# 1          53.27  ...                 7.11                   9.39
# 2          32.52  ...                 6.93                  14.13
# 3          59.57  ...                 4.04                   8.33
# 4           51.3  ...                 7.32                  15.28
#
#   reprobaci_n_media repitencia repitencia_transici_n repitencia_primaria  \
# 0              2.04       9.52                     0               10.46
# 1              1.75       9.34                  6.95               11.84
# 2              7.81       8.65                  6.67                9.04
# 3               4.6      16.18                  7.75               21.04
# 4              7.27       9.24                  2.86                7.62
#
#   repitencia_secundaria repitencia_media tama_o_promedio_de_grupo  \
# 0                 13.76             2.04                      NaN
# 1                  8.48             3.16                      NaN
# 2                 10.25             1.54                      NaN
# 3                 13.84             7.18                      NaN
# 4                 14.85             3.64                      NaN
#
#   sedes_conectadas_a_internet
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#
# [5 rows x 41 columns]

# %% [markdown]
# ## Aprendiendo pandas
#
# Queremos obtener una información sencilla del conjunto de datos

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14585 entries, 0 to 14584
# Data columns (total 41 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   a_o                          14585 non-null  object
#  1   c_digo_municipio             14585 non-null  object
#  2   municipio                    14585 non-null  object
#  3   c_digo_departamento          14585 non-null  object
#  4   departamento                 14585 non-null  object
#  5   c_digo_etc                   14585 non-null  object
#  6   etc                          14585 non-null  object
#  7   poblaci_n_5_16               14579 non-null  object
#  8   tasa_matriculaci_n_5_16      14470 non-null  object
#  9   cobertura_neta               14474 non-null  object
#  10  cobertura_neta_transici_n    14533 non-null  object
#  11  cobertura_neta_primaria      14494 non-null  object
#  12  cobertura_neta_secundaria    14491 non-null  object
#  13  cobertura_neta_media         14492 non-null  object
#  14  cobertura_bruta              14517 non-null  object
#  15  cobertura_bruta_transici_n   14488 non-null  object
#  16  cobertura_bruta_primaria     14504 non-null  object
#  17  cobertura_bruta_secundaria   14497 non-null  object
#  18  cobertura_bruta_media        14458 non-null  object
#  19  deserci_n                    14443 non-null  object
#  20  deserci_n_transici_n         13682 non-null  object
#  21  deserci_n_primaria           14343 non-null  object
#  22  deserci_n_secundaria         14315 non-null  object
#  23  deserci_n_media              13851 non-null  object
#  24  aprobaci_n                   14560 non-null  object
#  25  aprobaci_n_transici_n        14492 non-null  object
#  26  aprobaci_n_primaria          14560 non-null  object
#  27  aprobaci_n_secundaria        14531 non-null  object
#  28  aprobaci_n_media             14484 non-null  object
#  29  reprobaci_n                  14499 non-null  object
#  30  reprobaci_n_transici_n       14492 non-null  object
#  31  reprobaci_n_primaria         14488 non-null  object
#  32  reprobaci_n_secundaria       14479 non-null  object
#  33  reprobaci_n_media            14440 non-null  object
#  34  repitencia                   14442 non-null  object
#  35  repitencia_transici_n        14426 non-null  object
#  36  repitencia_primaria          14437 non-null  object
#  37  repitencia_secundaria        14433 non-null  object
#  38  repitencia_media             14446 non-null  object
#  39  tama_o_promedio_de_grupo     7572 non-null   object
#  40  sedes_conectadas_a_internet  7768 non-null   object
# dtypes: object(41)
# memory usage: 4.6+ MB

# %% [markdown]
# Generemos una "muestra" del conjunto de datos
#
# 1. Tomando los primeros registros del conjunto de datos.

# %%
pd.set_option('display.max_columns', None)

# %%
df_raw.head(15)
# Out:
#      a_o c_digo_municipio              municipio c_digo_departamento  \
# 0   2023            05004               Abriaquí                  05
# 1   2023            95025             El Retorno                  95
# 2   2023            95200             Miraflores                  95
# 3   2023            97001                   Mitú                  97
# 4   2023            97161                 Caruru                  97
# 5   2023            97511                  Pacoa                  97
# 6   2023            97666                Taraira                  97
# 7   2023            97777               Papunaua                  97
# 8   2023            97889               Yavaraté                  97
# 9   2023            99001         Puerto Carreño                  99
# 10  2023            99524           La Primavera                  99
# 11  2023            99624          Santa Rosalía                  99
# 12  2023            99773               Cumaribo                  99
# 13  2023            95001  San José del Guaviare                  95
# 14  2023            94887              Pana Pana                  94
#
#    departamento c_digo_etc              etc poblaci_n_5_16  \
# 0     Antioquia       3758  Antioquia (ETC)            503
# 1      Guaviare       3830   Guaviare (ETC)           4438
# 2      Guaviare       3830   Guaviare (ETC)           2014
# 3        Vaupés       3831     Vaupés (ETC)          10986
# 4        Vaupés       3831     Vaupés (ETC)           1228
# 5        Vaupés       3831     Vaupés (ETC)           1678
# 6        Vaupés       3831     Vaupés (ETC)            814
# 7        Vaupés       3831     Vaupés (ETC)            209
# 8        Vaupés       3831     Vaupés (ETC)            561
# 9       Vichada       3832    Vichada (ETC)           4641
# 10      Vichada       3832    Vichada (ETC)           2659
# 11      Vichada       3832    Vichada (ETC)           1159
# 12      Vichada       3832    Vichada (ETC)          25357
# 13     Guaviare       3830   Guaviare (ETC)          13980
# 14      Guainía       3829    Guainía (ETC)            718
#
#    tasa_matriculaci_n_5_16 cobertura_neta cobertura_neta_transici_n  \
# 0                    62.62          62.62                     44.19
# 1                    53.27          53.27                     33.91
# 2                    32.52          32.52                     17.58
# 3                    59.57          59.57                     42.76
# 4                     51.3           51.3                     76.32
# 5                    54.29          54.29                     15.44
# 6                     22.6           22.6                     14.29
# 7                        0              0                         0
# 8                    47.95          47.95                     68.75
# 9                   144.52         144.52                    114.44
# 10                   95.94          95.94                     73.37
# 11                   83.87          83.87                     64.94
# 12                   49.85          49.85                     38.19
# 13                   90.57          90.54                     54.89
# 14                   37.33          37.33                     30.14
#
#    cobertura_neta_primaria cobertura_neta_secundaria cobertura_neta_media  \
# 0                    63.33                     51.53                40.23
# 1                    48.89                      44.9                 21.3
# 2                    25.33                     26.43                10.75
# 3                    55.95                     43.51                17.06
# 4                    52.29                     33.71                11.94
# 5                    55.69                     24.91                 4.62
# 6                    34.98                         0                    0
# 7                        0                         0                    0
# 8                    52.19                     25.84                13.04
# 9                   162.78                     78.48                33.46
# 10                  102.36                     60.71                29.68
# 11                   85.74                     54.05                27.75
# 12                   57.31                     16.07                 3.96
# 13                    83.5                     72.82                40.81
# 14                   39.93                      11.2                    0
#
#    cobertura_bruta cobertura_bruta_transici_n cobertura_bruta_primaria  \
# 0             66.8                      58.14                    72.86
# 1            62.98                       54.2                    65.19
# 2            38.58                      36.36                    37.28
# 3            70.65                       64.9                    76.96
# 4            55.54                      92.11                    65.21
# 5            71.39                      38.93                    100.3
# 6            23.34                      23.81                    57.76
# 7                0                          0                        0
# 8            52.05                        100                    69.74
# 9            158.5                     145.45                   225.67
# 10          105.45                      108.7                   135.63
# 11            93.1                     111.69                   112.81
# 12           56.18                      55.67                    87.14
# 13          108.76                      93.07                   115.89
# 14           44.85                      39.73                    72.53
#
#    cobertura_bruta_secundaria cobertura_bruta_media deserci_n  \
# 0                       66.87                 56.32      1.19
# 1                        69.6                 48.54      5.56
# 2                        46.1                 26.16      7.85
# 3                       72.92                 53.12      3.95
# 4                       51.12                 27.36      8.36
# 5                       67.92                 30.03      5.35
# 6                           0                     0         0
# 7                           0                     0         0
# 8                       36.36                 27.17      4.45
# 9                      122.55                 75.43      5.81
# 10                      94.33                 58.28      6.44
# 11                      83.78                  55.5      4.91
# 12                      36.16                 16.88       7.5
# 13                     112.22                 91.92      5.87
# 14                      30.89                 13.27       2.8
#
#    deserci_n_transici_n deserci_n_primaria deserci_n_secundaria  \
# 0                     0               1.31                    0
# 1                  6.95               4.99                 6.11
# 2                    15               8.43                 6.36
# 3                  2.27               1.84                 6.77
# 4                  4.29               3.05                15.72
# 5                     0               7.16                 2.65
# 6                     0                  0                    0
# 7                     0                  0                    0
# 8                     0               1.89                 6.58
# 9                  5.54               6.12                  5.8
# 10                 7.77               4.88                 9.02
# 11                 4.65               4.03                 6.45
# 12                 5.72               7.52                 8.61
# 13                 8.41               4.95                 7.51
# 14                    0               1.01                 8.75
#
#    deserci_n_media aprobaci_n aprobaci_n_transici_n aprobaci_n_primaria  \
# 0             4.08      92.26                     0               96.73
# 1             5.26      87.67                     0                87.9
# 2             4.69      82.68                  3.33               84.64
# 3             5.47      90.71                  0.57               94.12
# 4            14.55       82.4                     0               89.63
# 5             6.59      94.65                     0               92.84
# 6                0        100                     0                 100
# 7                0          0                     0                   0
# 8               20      95.55                     0               98.11
# 9              3.3      80.93                     0               80.92
# 10            5.17      83.33                     0               81.66
# 11            4.72      85.26                     0               88.28
# 12            5.13      76.05                  0.09               71.13
# 13            3.08      85.04                  0.32               88.21
# 14               0      88.51                     0               92.42
#
#    aprobaci_n_secundaria aprobaci_n_media reprobaci_n reprobaci_n_transici_n  \
# 0                  83.49            93.88        6.55                      0
# 1                   84.5            92.98        6.78                      0
# 2                  79.51             87.5        9.47                   3.33
# 3                  84.91            89.93        5.34                   0.57
# 4                     69            78.18        9.24                      0
# 5                  97.35            93.41           0                      0
# 6                      0                0           0                      0
# 7                      0                0           0                      0
# 8                  93.42               80           0                      0
# 9                  75.36            87.89       13.26                      0
# 10                 82.07            90.04       10.23                      0
# 11                 75.66            92.45        9.82                      0
# 12                 81.52            89.74       16.45                   0.09
# 13                  76.8            91.25        9.09                   0.32
# 14                  72.5              100         8.7                      0
#
#    reprobaci_n_primaria reprobaci_n_secundaria reprobaci_n_media repitencia  \
# 0                  1.96                  16.51              2.04       9.52
# 1                  7.11                   9.39              1.75       9.34
# 2                  6.93                  14.13              7.81       8.65
# 3                  4.04                   8.33               4.6      16.18
# 4                  7.32                  15.28              7.27       9.24
# 5                     0                      0                 0      23.21
# 6                     0                      0                 0      21.58
# 7                     0                      0                 0          0
# 8                     0                      0                 0      12.33
# 9                 12.96                  18.84              8.81      11.18
# 10                13.46                   8.91               4.8      13.98
# 11                 7.69                  17.89              2.83      13.99
# 12                21.35                   9.87              5.13      21.27
# 13                 6.84                  15.69              5.67      10.84
# 14                 6.57                  18.75                 0      31.37
#
#    repitencia_transici_n repitencia_primaria repitencia_secundaria  \
# 0                      0               10.46                 13.76
# 1                   6.95               11.84                  8.48
# 2                   6.67                9.04                 10.25
# 3                   7.75               21.04                 13.84
# 4                   2.86                7.62                 14.85
# 5                  25.86                30.3                 14.25
# 6                  13.33               22.29                     0
# 7                      0                   0                     0
# 8                   3.13                19.5                  3.95
# 9                   0.82               13.25                 10.45
# 10                  1.55               19.37                  11.8
# 11                     0               16.48                 17.01
# 12                  0.52               27.83                 11.87
# 13                  6.83               11.44                 13.61
# 14                     0               42.93                 18.75
#
#    repitencia_media tama_o_promedio_de_grupo sedes_conectadas_a_internet
# 0              2.04                      NaN                         NaN
# 1              3.16                      NaN                         NaN
# 2              1.54                      NaN                         NaN
# 3              7.18                      NaN                         NaN
# 4              3.64                      NaN                         NaN
# 5              6.59                      NaN                         NaN
# 6                 0                      NaN                         NaN
# 7                 0                      NaN                         NaN
# 8                 4                      NaN                         NaN
# 9              6.39                      NaN                         NaN
# 10             1.48                      NaN                         NaN
# 11             2.83                      NaN                         NaN
# 12             6.56                      NaN                         NaN
# 13             1.92                      NaN                         NaN
# 14             6.67                      NaN                         NaN

# %% [markdown]
# 2. Ahora, usamos los índices para mostrar una fracción del conjunto de datos.

# %%
df_raw.iloc[20:30] # Pensemos en estos índices como un intervalo semi abierto [20,30)
# Out:
#      a_o c_digo_municipio         municipio c_digo_departamento departamento  \
# 20  2023            94001           Inírida                  94      Guainía
# 21  2023            91798          Tarapacá                  91     Amazonas
# 22  2023            91669  Puerto Santander                  91     Amazonas
# 23  2023            91540     Puerto Nariño                  91     Amazonas
# 24  2023            91536      Puerto Arica                  91     Amazonas
# 25  2023            91530    Puerto Alegría                  91     Amazonas
# 26  2023            91460   Miriti - Paraná                  91     Amazonas
# 27  2023            91430       La Victoria                  91     Amazonas
# 28  2023            91407        La Pedrera                  91     Amazonas
# 29  2023            91405       La Chorrera                  91     Amazonas
#
#    c_digo_etc             etc poblaci_n_5_16 tasa_matriculaci_n_5_16  \
# 20       3829   Guainía (ETC)           9673                   77.42
# 21       3828  Amazonas (ETC)           1327                   50.04
# 22       3828  Amazonas (ETC)            618                   63.75
# 23       3828  Amazonas (ETC)           3232                   55.07
# 24       3828  Amazonas (ETC)            274                   83.94
# 25       3828  Amazonas (ETC)            211                    65.4
# 26       3828  Amazonas (ETC)            571                   49.39
# 27       3828  Amazonas (ETC)            169                    14.2
# 28       3828  Amazonas (ETC)           1203                   67.17
# 29       3828  Amazonas (ETC)           1197                   50.04
#
#    cobertura_neta cobertura_neta_transici_n cobertura_neta_primaria  \
# 20          77.33                      72.7                   73.75
# 21          50.04                     33.94                   62.02
# 22          63.75                     72.34                   78.03
# 23          55.07                     37.74                   53.98
# 24          83.94                     44.44                    87.1
# 25           65.4                     40.91                   63.64
# 26          49.39                     11.63                   54.11
# 27           14.2                     23.53                   15.49
# 28          67.17                     55.67                    77.6
# 29          50.04                     48.75                   45.03
#
#    cobertura_neta_secundaria cobertura_neta_media cobertura_bruta  \
# 20                     45.35                13.11           89.34
# 21                     19.96                 3.08           55.16
# 22                      27.1                11.83           69.74
# 23                     39.01                16.28           63.18
# 24                     55.95                20.51           95.26
# 25                      37.5                    0           68.72
# 26                     27.13                11.01           58.84
# 27                         0                    0            14.2
# 28                     34.95                19.07           79.97
# 29                     33.93                  9.9           57.81
#
#    cobertura_bruta_transici_n cobertura_bruta_primaria  \
# 20                     106.92                   108.59
# 21                      71.56                    87.71
# 22                     114.89                    98.11
# 23                      73.15                    73.34
# 24                      81.48                   120.16
# 25                      77.27                    96.97
# 26                      39.53                    78.35
# 27                      29.41                    26.76
# 28                     117.53                    100.8
# 29                       67.5                    61.35
#
#    cobertura_bruta_secundaria cobertura_bruta_media deserci_n  \
# 20                      82.48                 47.78      6.42
# 21                       35.2                  8.37      2.19
# 22                      41.59                 31.18      0.95
# 23                      58.83                 41.38      9.67
# 24                      79.76                 58.97         0
# 25                         50                     0      1.38
# 26                      53.19                 34.86     10.42
# 27                          0                     0         0
# 28                      61.17                 47.42      0.77
# 29                      61.73                 35.94      5.38
#
#    deserci_n_transici_n deserci_n_primaria deserci_n_secundaria  \
# 20                 6.75               5.08                 9.29
# 21                    0               0.21                 8.28
# 22                 1.85               0.39                 2.25
# 23                 5.85               7.59                12.28
# 24                    0                  0                    0
# 25                    0                  0                 6.25
# 26                 5.88               2.21                   21
# 27                    0                  0                    0
# 28                    0                  0                 1.32
# 29                    0               2.45                11.36
#
#    deserci_n_media aprobaci_n aprobaci_n_transici_n aprobaci_n_primaria  \
# 20            3.66      81.12                  1.46               81.57
# 21           10.53      90.16                     0               98.54
# 22               0      95.48                     0               96.53
# 23           15.43      78.27                     0                78.9
# 24               0      99.62                     0               99.33
# 25               0      91.03                     0               90.63
# 26           23.68      89.58                     0               97.79
# 27               0        100                     0                 100
# 28            6.15      97.14                     0                99.4
# 29               4      84.33                  5.56               85.93
#
#    aprobaci_n_secundaria aprobaci_n_media reprobaci_n reprobaci_n_transici_n  \
# 20                 75.11            89.01       12.46                   1.46
# 21                 67.52            26.32        7.65                      0
# 22                 89.89              100        3.57                      0
# 23                 72.25            79.26       12.06                      0
# 24                   100              100        0.38                      0
# 25                  87.5                0        7.59                      0
# 26                    79            76.32           0                      0
# 27                     0                0           0                      0
# 28                 92.95            89.23        2.09                      0
# 29                    80               82       10.29                   5.56
#
#    reprobaci_n_primaria reprobaci_n_secundaria reprobaci_n_media repitencia  \
# 20                13.35                   15.6              7.33      16.19
# 21                 1.26                   24.2             63.16      26.09
# 22                 3.09                   7.87                 0      16.67
# 23                13.51                  15.47              5.32      15.37
# 24                 0.67                      0                 0      11.49
# 25                 9.38                   6.25                 0      18.62
# 26                    0                      0                 0       12.5
# 27                    0                      0                 0      16.67
# 28                  0.6                   5.73              4.62      12.97
# 29                11.62                   8.64                14      26.42
#
#    repitencia_transici_n repitencia_primaria repitencia_secundaria  \
# 20                  8.47               18.36                 17.25
# 21                  1.28               28.87                  29.3
# 22                  1.85               19.69                 16.85
# 23                  5.85               18.61                 16.75
# 24                     0               12.75                 10.45
# 25                 29.41               19.79                  9.38
# 26                 17.65               11.05                    18
# 27                    20               15.79                     0
# 28                  2.63               20.24                  4.85
# 29                  5.56               24.77                 37.27
#
#    repitencia_media tama_o_promedio_de_grupo sedes_conectadas_a_internet
# 20             6.11                      NaN                         NaN
# 21            31.58                      NaN                         NaN
# 22            16.67                      NaN                         NaN
# 23             3.72                      NaN                         NaN
# 24            17.39                      NaN                         NaN
# 25                0                      NaN                         NaN
# 26             2.63                      NaN                         NaN
# 27                0                      NaN                         NaN
# 28             3.08                      NaN                         NaN
# 29               12                      NaN                         NaN

# %%
df_raw.iloc[20:30,1:6]
# Out:
#    c_digo_municipio         municipio c_digo_departamento departamento  \
# 20            94001           Inírida                  94      Guainía
# 21            91798          Tarapacá                  91     Amazonas
# 22            91669  Puerto Santander                  91     Amazonas
# 23            91540     Puerto Nariño                  91     Amazonas
# 24            91536      Puerto Arica                  91     Amazonas
# 25            91530    Puerto Alegría                  91     Amazonas
# 26            91460   Miriti - Paraná                  91     Amazonas
# 27            91430       La Victoria                  91     Amazonas
# 28            91407        La Pedrera                  91     Amazonas
# 29            91405       La Chorrera                  91     Amazonas
#
#    c_digo_etc
# 20       3829
# 21       3828
# 22       3828
# 23       3828
# 24       3828
# 25       3828
# 26       3828
# 27       3828
# 28       3828
# 29       3828

# %%
df_raw.loc[20:30] # Pensemos en estos índices como un intervalo cerrado [20,30]
# Out:
#      a_o c_digo_municipio         municipio c_digo_departamento departamento  \
# 20  2023            94001           Inírida                  94      Guainía
# 21  2023            91798          Tarapacá                  91     Amazonas
# 22  2023            91669  Puerto Santander                  91     Amazonas
# 23  2023            91540     Puerto Nariño                  91     Amazonas
# 24  2023            91536      Puerto Arica                  91     Amazonas
# 25  2023            91530    Puerto Alegría                  91     Amazonas
# 26  2023            91460   Miriti - Paraná                  91     Amazonas
# 27  2023            91430       La Victoria                  91     Amazonas
# 28  2023            91407        La Pedrera                  91     Amazonas
# 29  2023            91405       La Chorrera                  91     Amazonas
# 30  2023            91263        El Encanto                  91     Amazonas
#
#    c_digo_etc             etc poblaci_n_5_16 tasa_matriculaci_n_5_16  \
# 20       3829   Guainía (ETC)           9673                   77.42
# 21       3828  Amazonas (ETC)           1327                   50.04
# 22       3828  Amazonas (ETC)            618                   63.75
# 23       3828  Amazonas (ETC)           3232                   55.07
# 24       3828  Amazonas (ETC)            274                   83.94
# 25       3828  Amazonas (ETC)            211                    65.4
# 26       3828  Amazonas (ETC)            571                   49.39
# 27       3828  Amazonas (ETC)            169                    14.2
# 28       3828  Amazonas (ETC)           1203                   67.17
# 29       3828  Amazonas (ETC)           1197                   50.04
# 30       3828  Amazonas (ETC)            656                   49.09
#
#    cobertura_neta cobertura_neta_transici_n cobertura_neta_primaria  \
# 20          77.33                      72.7                   73.75
# 21          50.04                     33.94                   62.02
# 22          63.75                     72.34                   78.03
# 23          55.07                     37.74                   53.98
# 24          83.94                     44.44                    87.1
# 25           65.4                     40.91                   63.64
# 26          49.39                     11.63                   54.11
# 27           14.2                     23.53                   15.49
# 28          67.17                     55.67                    77.6
# 29          50.04                     48.75                   45.03
# 30          49.09                     16.36                   58.05
#
#    cobertura_neta_secundaria cobertura_neta_media cobertura_bruta  \
# 20                     45.35                13.11           89.34
# 21                     19.96                 3.08           55.16
# 22                      27.1                11.83           69.74
# 23                     39.01                16.28           63.18
# 24                     55.95                20.51           95.26
# 25                      37.5                    0           68.72
# 26                     27.13                11.01           58.84
# 27                         0                    0            14.2
# 28                     34.95                19.07           79.97
# 29                     33.93                  9.9           57.81
# 30                     32.74                17.12           52.59
#
#    cobertura_bruta_transici_n cobertura_bruta_primaria  \
# 20                     106.92                   108.59
# 21                      71.56                    87.71
# 22                     114.89                    98.11
# 23                      73.15                    73.34
# 24                      81.48                   120.16
# 25                      77.27                    96.97
# 26                      39.53                    78.35
# 27                      29.41                    26.76
# 28                     117.53                    100.8
# 29                       67.5                    61.35
# 30                      32.73                    73.41
#
#    cobertura_bruta_secundaria cobertura_bruta_media deserci_n  \
# 20                      82.48                 47.78      6.42
# 21                       35.2                  8.37      2.19
# 22                      41.59                 31.18      0.95
# 23                      58.83                 41.38      9.67
# 24                      79.76                 58.97         0
# 25                         50                     0      1.38
# 26                      53.19                 34.86     10.42
# 27                          0                     0         0
# 28                      61.17                 47.42      0.77
# 29                      61.73                 35.94      5.38
# 30                      44.84                 27.93      8.16
#
#    deserci_n_transici_n deserci_n_primaria deserci_n_secundaria  \
# 20                 6.75               5.08                 9.29
# 21                    0               0.21                 8.28
# 22                 1.85               0.39                 2.25
# 23                 5.85               7.59                12.28
# 24                    0                  0                    0
# 25                    0                  0                 6.25
# 26                 5.88               2.21                   21
# 27                    0                  0                    0
# 28                    0                  0                 1.32
# 29                    0               2.45                11.36
# 30                11.11               1.53                   17
#
#    deserci_n_media aprobaci_n aprobaci_n_transici_n aprobaci_n_primaria  \
# 20            3.66      81.12                  1.46               81.57
# 21           10.53      90.16                     0               98.54
# 22               0      95.48                     0               96.53
# 23           15.43      78.27                     0                78.9
# 24               0      99.62                     0               99.33
# 25               0      91.03                     0               90.63
# 26           23.68      89.58                     0               97.79
# 27               0        100                     0                 100
# 28            6.15      97.14                     0                99.4
# 29               4      84.33                  5.56               85.93
# 30           20.69       89.8                     0               97.45
#
#    aprobaci_n_secundaria aprobaci_n_media reprobaci_n reprobaci_n_transici_n  \
# 20                 75.11            89.01       12.46                   1.46
# 21                 67.52            26.32        7.65                      0
# 22                 89.89              100        3.57                      0
# 23                 72.25            79.26       12.06                      0
# 24                   100              100        0.38                      0
# 25                  87.5                0        7.59                      0
# 26                    79            76.32           0                      0
# 27                     0                0           0                      0
# 28                 92.95            89.23        2.09                      0
# 29                    80               82       10.29                   5.56
# 30                    78            79.31        2.04                      0
#
#    reprobaci_n_primaria reprobaci_n_secundaria reprobaci_n_media repitencia  \
# 20                13.35                   15.6              7.33      16.19
# 21                 1.26                   24.2             63.16      26.09
# 22                 3.09                   7.87                 0      16.67
# 23                13.51                  15.47              5.32      15.37
# 24                 0.67                      0                 0      11.49
# 25                 9.38                   6.25                 0      18.62
# 26                    0                      0                 0       12.5
# 27                    0                      0                 0      16.67
# 28                  0.6                   5.73              4.62      12.97
# 29                11.62                   8.64                14      26.42
# 30                 1.02                      5                 0       9.62
#
#    repitencia_transici_n repitencia_primaria repitencia_secundaria  \
# 20                  8.47               18.36                 17.25
# 21                  1.28               28.87                  29.3
# 22                  1.85               19.69                 16.85
# 23                  5.85               18.61                 16.75
# 24                     0               12.75                 10.45
# 25                 29.41               19.79                  9.38
# 26                 17.65               11.05                    18
# 27                    20               15.79                     0
# 28                  2.63               20.24                  4.85
# 29                  5.56               24.77                 37.27
# 30                     0                9.18                    14
#
#    repitencia_media tama_o_promedio_de_grupo sedes_conectadas_a_internet
# 20             6.11                      NaN                         NaN
# 21            31.58                      NaN                         NaN
# 22            16.67                      NaN                         NaN
# 23             3.72                      NaN                         NaN
# 24            17.39                      NaN                         NaN
# 25                0                      NaN                         NaN
# 26             2.63                      NaN                         NaN
# 27                0                      NaN                         NaN
# 28             3.08                      NaN                         NaN
# 29               12                      NaN                         NaN
# 30             3.45                      NaN                         NaN

# %% [markdown]
# 3. Tomar una muestra aleatoria del conjunto de datos

# %%
df_raw.sample(frac = 0.01, random_state=123456)
# Out:
#         a_o c_digo_municipio     municipio c_digo_departamento departamento  \
# 10516  2014            50330       Mesetas                  50         Meta
# 2152   2022             5628   Sabanalarga                   5    Antioquia
# 9454   2015            41660  Saladoblanco                  41        Huila
# 10130  2014            97889      Yavaraté                  97       Vaupés
# 11152  2014             5411      Liborina                   5    Antioquia
# ...     ...              ...           ...                 ...          ...
# 4912   2019            50251   El Castillo                  50         Meta
# 11711  2013            41503       Oporapa                  41        Huila
# 9773   2015            15897     Zetaquira                  15       Boyacá
# 3428   2020            81065     Arauquita                  81       Arauca
# 8460   2016            41006       Acevedo                  41        Huila
#
#       c_digo_etc              etc poblaci_n_5_16 tasa_matriculaci_n_5_16  \
# 10516       3796       Meta (ETC)           2904                   76.41
# 2152        3758  Antioquia (ETC)           2046                   79.33
# 9454        3790      Huila (ETC)           3108                   86.87
# 10130       3831     Vaupés (ETC)            386                   75.39
# 11152       3758  Antioquia (ETC)           1985                  105.29
# ...          ...              ...            ...                     ...
# 4912        3796       Meta (ETC)           1766                   95.13
# 11711       3790      Huila (ETC)           3997                   68.83
# 9773        3769     Boyacá (ETC)            981                   97.96
# 3428        3824     Arauca (ETC)          13580                   68.03
# 8460        3790      Huila (ETC)           9107                      81
#
#       cobertura_neta cobertura_neta_transici_n cobertura_neta_primaria  \
# 10516          89.01                     69.94                   74.11
# 2152           79.33                        50                   75.84
# 9454           86.87                     70.44                   90.16
# 10130          87.65                        52                   70.59
# 11152          89.66                     71.79                   77.81
# ...              ...                       ...                     ...
# 4912           95.13                      58.7                   94.09
# 11711           68.8                      67.8                    77.4
# 9773           97.96                      74.7                   84.56
# 3428           68.03                     42.21                   67.19
# 8460           81.04                     55.85                   90.25
#
#       cobertura_neta_secundaria cobertura_neta_media cobertura_bruta  \
# 10516                     66.11                43.68           85.85
# 2152                      72.38                34.94           85.58
# 9454                      72.23                30.36           96.59
# 10130                     60.76                33.33           86.01
# 11152                     68.57                56.41          117.43
# ...                         ...                  ...             ...
# 4912                      78.35                43.73          102.49
# 11711                      58.5                   26            73.9
# 9773                      100.3                70.07          107.03
# 3428                      53.53                 24.5           76.08
# 8460                      66.12                27.21           90.04
#
#       cobertura_bruta_transici_n cobertura_bruta_primaria  \
# 10516                      64.17                   116.79
# 2152                       66.15                    92.17
# 9454                       93.43                   113.17
# 10130                      80.65                   125.15
# 11152                     109.09                    149.4
# ...                          ...                      ...
# 4912                       84.78                   115.52
# 11711                       79.8                     88.7
# 9773                       81.93                    96.44
# 3428                       70.52                    88.75
# 8460                       72.96                   108.84
#
#       cobertura_bruta_secundaria cobertura_bruta_media deserci_n  \
# 10516                      75.39                  37.5      1.89
# 2152                       95.52                 58.01       1.8
# 9454                       98.53                    50       4.3
# 10130                      60.77                 38.71      2.71
# 11152                     112.55                 68.94      1.53
# ...                          ...                   ...       ...
# 4912                      106.28                 70.85      6.29
# 11711                       69.3                  41.4      3.84
# 9773                      116.67                129.93      0.99
# 3428                       75.03                 47.58      4.39
# 8460                       89.44                 51.59      3.59
#
#       deserci_n_transici_n deserci_n_primaria deserci_n_secundaria  \
# 10516                 0.65               2.27                 1.61
# 2152                  2.36               1.09                 2.78
# 9454                  3.91               3.13                    6
# 10130                  NaN               1.96                 6.33
# 11152                 0.64               0.63                 3.19
# ...                    ...                ...                  ...
# 4912                  3.42               3.58                11.17
# 11711                 1.51               2.23                 7.41
# 9773                   NaN               0.49                  0.8
# 3428                  3.97               4.22                 4.56
# 8460                  3.45               1.92                 5.82
#
#       deserci_n_media aprobaci_n aprobaci_n_transici_n aprobaci_n_primaria  \
# 10516            0.81      98.11                     0               97.73
# 2152             1.38      97.54                     0               98.18
# 9454             5.88      92.62                     0               91.31
# 10130             NaN      97.29                     0               98.04
# 11152            1.51      98.47                     0               99.37
# ...               ...        ...                   ...                 ...
# 4912             4.81       90.2                     0               92.25
# 11711            3.17      90.37                     0                93.3
# 9773             3.03      96.75                     0               99.51
# 3428             5.33      85.71                  3.49               87.82
# 8460             7.69       89.6                     0               92.77
#
#       aprobaci_n_secundaria aprobaci_n_media reprobaci_n  \
# 10516                 98.39            99.19           0
# 2152                  96.35            98.62        0.66
# 9454                  93.53            93.67        3.07
# 10130                 93.67              100           0
# 11152                 96.81            98.49           0
# ...                     ...              ...         ...
# 4912                  84.94            93.58        3.52
# 11711                 83.45            88.69        5.79
# 9773                  94.68            93.33        2.27
# 3428                  79.93            87.31         9.9
# 8460                  82.93            85.04        6.81
#
#       reprobaci_n_transici_n reprobaci_n_primaria reprobaci_n_secundaria  \
# 10516                      0                    0                      0
# 2152                       0                 0.73                   0.87
# 9454                       0                 5.56                   0.47
# 10130                      0                    0                      0
# 11152                      0                    0                      0
# ...                      ...                  ...                    ...
# 4912                       0                 4.17                   3.89
# 11711                      0                 4.47                   9.14
# 9773                       0                    0                   4.52
# 3428                    3.49                 7.96                  15.51
# 8460                       0                 5.31                  11.24
#
#       reprobaci_n_media repitencia repitencia_transici_n repitencia_primaria  \
# 10516                 0          0                     0                   0
# 2152                  0       8.32                     0               12.39
# 9454               0.45       2.68                  1.95                3.96
# 10130                 0       3.61                     0                 4.9
# 11152                 0       2.87                  2.56                2.34
# ...                 ...        ...                   ...                 ...
# 4912                1.6       1.44                     0                1.19
# 11711              8.14       1.26                     0                2.09
# 9773               3.64       0.79                     0                1.48
# 3428               7.36       6.42                  1.93                5.15
# 8460               7.26       3.42                  0.69                4.48
#
#       repitencia_secundaria repitencia_media tama_o_promedio_de_grupo  \
# 10516                     0                0                    25.59
# 2152                   6.09             1.38                      NaN
# 9454                   1.29             0.45                    33.45
# 10130                  2.53                0                     9.76
# 11152                  3.62             3.52                    27.09
# ...                     ...              ...                      ...
# 4912                   2.54                0                      NaN
# 11711                  0.58                0                      NaN
# 9773                   0.53                0                    27.27
# 3428                  10.88             2.03                      NaN
# 8460                   2.44             2.35                   27.244
#
#       sedes_conectadas_a_internet
# 10516                        1.75
# 2152                          NaN
# 9454                         12.5
# 10130                       16.67
# 11152                       73.53
# ...                           ...
# 4912                          NaN
# 11711                       11.11
# 9773                            0
# 3428                          NaN
# 8460                        14.29
#
# [146 rows x 41 columns]

# %%
df_raw.sample(n = 10, random_state=123456)
# Out:
#         a_o c_digo_municipio     municipio c_digo_departamento departamento  \
# 10516  2014            50330       Mesetas                  50         Meta
# 2152   2022             5628   Sabanalarga                   5    Antioquia
# 9454   2015            41660  Saladoblanco                  41        Huila
# 10130  2014            97889      Yavaraté                  97       Vaupés
# 11152  2014             5411      Liborina                   5    Antioquia
# 2210   2022             5134    Campamento                   5    Antioquia
# 6968   2017            68368   Jesús María                  68    Santander
# 8852   2016            73675   San Antonio                  73       Tolima
# 13385  2012             5475       Murindó                   5    Antioquia
# 2067   2022            13458   Montecristo                  13      Bolívar
#
#       c_digo_etc              etc poblaci_n_5_16 tasa_matriculaci_n_5_16  \
# 10516       3796       Meta (ETC)           2904                   76.41
# 2152        3758  Antioquia (ETC)           2046                   79.33
# 9454        3790      Huila (ETC)           3108                   86.87
# 10130       3831     Vaupés (ETC)            386                   75.39
# 11152       3758  Antioquia (ETC)           1985                  105.29
# 2210        3758  Antioquia (ETC)           2223                   72.15
# 6968        3808  Santander (ETC)            657                    87.2
# 8852        3815     Tolima (ETC)           3510                    90.9
# 13385       3758  Antioquia (ETC)           1023                    95.6
# 2067        3767    Bolívar (ETC)           4308                   75.35
#
#       cobertura_neta cobertura_neta_transici_n cobertura_neta_primaria  \
# 10516          89.01                     69.94                   74.11
# 2152           79.33                        50                   75.84
# 9454           86.87                     70.44                   90.16
# 10130          87.65                        52                   70.59
# 11152          89.66                     71.79                   77.81
# 2210           72.15                     40.46                   72.37
# 6968           87.21                     45.76                      75
# 8852           90.85                     47.04                   90.09
# 13385           95.6                      62.8                   106.2
# 2067           75.35                     46.67                   74.08
#
#       cobertura_neta_secundaria cobertura_neta_media cobertura_bruta  \
# 10516                     66.11                43.68           85.85
# 2152                      72.38                34.94           85.58
# 9454                      72.23                30.36           96.59
# 10130                     60.76                33.33           86.01
# 11152                     68.57                56.41          117.43
# 2210                      55.45                31.15           81.38
# 6968                      88.57                72.32           97.72
# 8852                      80.86                40.97          102.36
# 13385                        24                   10           103.5
# 2067                      48.47                 9.74           83.22
#
#       cobertura_bruta_transici_n cobertura_bruta_primaria  \
# 10516                      64.17                   116.79
# 2152                       66.15                    92.17
# 9454                       93.43                   113.17
# 10130                      80.65                   125.15
# 11152                     109.09                    149.4
# 2210                       54.34                    91.55
# 6968                       79.66                     83.7
# 8852                        67.6                   108.26
# 13385                       71.8                    190.3
# 2067                      106.67                   104.26
#
#       cobertura_bruta_secundaria cobertura_bruta_media deserci_n  \
# 10516                      75.39                  37.5      1.89
# 2152                       95.52                 58.01       1.8
# 9454                       98.53                    50       4.3
# 10130                      60.77                 38.71      2.71
# 11152                     112.55                 68.94      1.53
# 2210                       82.79                 65.57      5.71
# 6968                      113.33                 112.5      1.79
# 8852                      112.91                 84.17      4.82
# 13385                       47.7                  19.4      4.06
# 2067                       74.35                 21.73      8.08
#
#       deserci_n_transici_n deserci_n_primaria deserci_n_secundaria  \
# 10516                 0.65               2.27                 1.61
# 2152                  2.36               1.09                 2.78
# 9454                  3.91               3.13                    6
# 10130                  NaN               1.96                 6.33
# 11152                 0.64               0.63                 3.19
# 2210                  3.19               4.02                 9.62
# 6968                  4.26               0.87                 3.14
# 8852                  4.61               4.27                 6.05
# 13385                 5.36               1.99                11.04
# 2067                 11.61               5.68                12.01
#
#       deserci_n_media aprobaci_n aprobaci_n_transici_n aprobaci_n_primaria  \
# 10516            0.81      98.11                     0               97.73
# 2152             1.38      97.54                     0               98.18
# 9454             5.88      92.62                     0               91.31
# 10130             NaN      97.29                     0               98.04
# 11152            1.51      98.47                     0               99.37
# 2210             2.65      86.65                     0               85.56
# 6968                0      92.37                     0               94.37
# 8852             3.39      88.49                     0               89.13
# 13385             NaN      95.94                     0               98.01
# 2067             4.46      82.18                  1.79               83.45
#
#       aprobaci_n_secundaria aprobaci_n_media reprobaci_n  \
# 10516                 98.39            99.19           0
# 2152                  96.35            98.62        0.66
# 9454                  93.53            93.67        3.07
# 10130                 93.67              100           0
# 11152                 96.81            98.49           0
# 2210                  83.39             96.3        7.65
# 6968                  87.44            96.52        5.84
# 8852                  85.38            91.53        6.69
# 13385                 88.96            82.86           0
# 2067                  75.87            93.75        9.74
#
#       reprobaci_n_transici_n reprobaci_n_primaria reprobaci_n_secundaria  \
# 10516                      0                    0                      0
# 2152                       0                 0.73                   0.87
# 9454                       0                 5.56                   0.47
# 10130                      0                    0                      0
# 11152                      0                    0                      0
# 2210                       0                10.41                   6.99
# 6968                       0                 4.76                   9.42
# 8852                       0                 6.59                   8.57
# 13385                      0                    0                      0
# 2067                    1.79                10.87                  12.12
#
#       reprobaci_n_media repitencia repitencia_transici_n repitencia_primaria  \
# 10516                 0          0                     0                   0
# 2152                  0       8.32                     0               12.39
# 9454               0.45       2.68                  1.95                3.96
# 10130                 0       3.61                     0                 4.9
# 11152                 0       2.87                  2.56                2.34
# 2210               1.06       9.12                     0               13.49
# 6968               3.48          0                     0                   0
# 8852               5.08       0.18                     0                0.12
# 13385                 0          0                     0                   0
# 2067               1.79      13.41                  3.79               16.19
#
#       repitencia_secundaria repitencia_media tama_o_promedio_de_grupo  \
# 10516                     0                0                    25.59
# 2152                   6.09             1.38                      NaN
# 9454                   1.29             0.45                    33.45
# 10130                  2.53                0                     9.76
# 11152                  3.62             3.52                    27.09
# 2210                   6.99             0.53                      NaN
# 6968                      0                0                   25.333
# 8852                   0.18             0.68                   24.985
# 13385                     0                0                    30.33
# 2067                   13.2             3.57                      NaN
#
#       sedes_conectadas_a_internet
# 10516                        1.75
# 2152                          NaN
# 9454                         12.5
# 10130                       16.67
# 11152                       73.53
# 2210                          NaN
# 6968                         8.33
# 8852                        56.67
# 13385                           5
# 2067                          NaN

# %%
df_raw.tail(20)
# Out:
#         a_o c_digo_municipio             municipio c_digo_departamento  \
# 14565  2011             5107               Briceño                   5
# 14566  2011             5101        Ciudad Bolívar                   5
# 14567  2011             5093               Betulia                   5
# 14568  2011             5091               Betania                   5
# 14569  2011             5088                 Bello                   5
# 14570  2011             5086               Belmira                   5
# 14571  2011             5079               Barbosa                   5
# 14572  2011             5059               Armenia                   5
# 14573  2011             5055               Argelia                   5
# 14574  2011             5051             Arboletes                   5
# 14575  2011             5045              Apartadó                   5
# 14576  2011             5044                  Anza                   5
# 14577  2011             5042  Santafé de Antioquia                   5
# 14578  2011             5040                 Anorí                   5
# 14579  2011             5038             Angostura                   5
# 14580  2011             5036           Angelópolis                   5
# 14581  2011             5034                 Andes                   5
# 14582  2011             5031                Amalfi                   5
# 14583  2011             5030                 Amagá                   5
# 14584  2011             5021            Alejandría                   5
#
#       departamento c_digo_etc              etc poblaci_n_5_16  \
# 14565    Antioquia       3758  Antioquia (ETC)           2256
# 14566    Antioquia       3758  Antioquia (ETC)           6651
# 14567    Antioquia       3758  Antioquia (ETC)           4260
# 14568    Antioquia       3758  Antioquia (ETC)           2345
# 14569    Antioquia       3760            Bello          91582
# 14570    Antioquia       3758  Antioquia (ETC)           1700
# 14571    Antioquia       3758  Antioquia (ETC)          10933
# 14572    Antioquia       3758  Antioquia (ETC)           1097
# 14573    Antioquia       3758  Antioquia (ETC)           2460
# 14574    Antioquia       3758  Antioquia (ETC)          10673
# 14575    Antioquia       7692         Apartado          45592
# 14576    Antioquia       3758  Antioquia (ETC)           1873
# 14577    Antioquia       3758  Antioquia (ETC)           5963
# 14578    Antioquia       3758  Antioquia (ETC)           3983
# 14579    Antioquia       3758  Antioquia (ETC)           3344
# 14580    Antioquia       3758  Antioquia (ETC)           1707
# 14581    Antioquia       3758  Antioquia (ETC)          10244
# 14582    Antioquia       3758  Antioquia (ETC)           5552
# 14583    Antioquia       3758  Antioquia (ETC)           6631
# 14584    Antioquia       3758  Antioquia (ETC)            702
#
#       tasa_matriculaci_n_5_16 cobertura_neta cobertura_neta_transici_n  \
# 14565                    94.1           94.1                      74.5
# 14566                   88.24           88.2                        70
# 14567                   95.45           95.5                      78.6
# 14568                   89.85           89.9                      58.6
# 14569                   82.53           82.4                      62.2
# 14570                   97.76           97.8                      96.5
# 14571                   82.05           82.1                      57.9
# 14572                   87.97             88                      67.4
# 14573                   88.58           88.6                      66.7
# 14574                   84.85           84.9                      71.1
# 14575                   66.51           66.5                      53.2
# 14576                   86.07           86.1                      60.9
# 14577                   84.59           84.6                      50.5
# 14578                   92.09           92.1                      82.9
# 14579                    81.7           81.7                      58.5
# 14580                   78.85           78.9                      56.2
# 14581                   84.45           84.5                      65.1
# 14582                   97.71           97.7                      61.7
# 14583                   78.65           78.7                      55.3
# 14584                  118.52          118.5                      82.7
#
#       cobertura_neta_primaria cobertura_neta_secundaria cobertura_neta_media  \
# 14565                    99.6                      49.1                 12.3
# 14566                    94.5                      64.3                 32.5
# 14567                     103                      64.4                 21.7
# 14568                    96.4                        59                 17.4
# 14569                    79.1                      71.6                 45.2
# 14570                   112.5                      61.6                   41
# 14571                    79.5                      71.8                 42.2
# 14572                    81.2                      72.7                 29.8
# 14573                    85.2                      66.4                 23.9
# 14574                      86                      55.9                 26.7
# 14575                    68.9                      48.3                 24.7
# 14576                    96.7                      49.3                 21.7
# 14577                    84.3                      62.4                 31.7
# 14578                   110.4                      51.1                 18.1
# 14579                    92.6                      49.6                 20.3
# 14580                    82.4                      59.9                 26.4
# 14581                    83.7                        62                 32.2
# 14582                   107.2                      65.1                 27.3
# 14583                    76.3                      70.7                 38.9
# 14584                   127.6                      90.2                 48.5
#
#       cobertura_bruta cobertura_bruta_transici_n cobertura_bruta_primaria  \
# 14565           106.9                      118.6                    143.2
# 14566              94                       81.6                    117.5
# 14567           105.2                       87.5                    133.2
# 14568            98.8                       73.2                    129.7
# 14569            93.3                       73.5                     94.6
# 14570           101.4                      107.1                    135.6
# 14571            88.1                         75                       96
# 14572            98.8                       83.2                    108.3
# 14573           103.7                       73.5                    118.5
# 14574           103.8                       87.6                    116.3
# 14575            78.7                       66.2                       87
# 14576            93.2                       89.7                    130.3
# 14577            97.8                       72.6                    112.3
# 14578           100.7                       85.7                    145.6
# 14579            90.8                       72.1                    122.2
# 14580            82.8                       77.4                      105
# 14581            91.7                       81.1                    107.5
# 14582           108.4                       77.9                    146.8
# 14583            87.7                       74.3                     89.8
# 14584           134.9                       86.5                    159.8
#
#       cobertura_bruta_secundaria cobertura_bruta_media deserci_n  \
# 14565                      100.4                  28.6      9.79
# 14566                         88                  53.6      5.97
# 14567                      100.2                  52.5         5
# 14568                       95.2                  41.4      2.65
# 14569                      103.8                  79.3      2.76
# 14570                       80.5                    59       6.9
# 14571                       92.6                  66.7      3.01
# 14572                      109.5                  63.4      5.19
# 14573                      110.8                  61.8      5.06
# 14574                        107                  72.7      3.18
# 14575                       81.6                  57.5      4.81
# 14576                       73.9                  39.8      2.19
# 14577                      101.6                  68.6      4.75
# 14578                       79.3                  44.8      6.26
# 14579                       78.8                  50.1      5.32
# 14580                       80.4                  40.1      8.14
# 14581                       89.9                  61.4      3.96
# 14582                       97.3                  53.9      8.75
# 14583                       96.3                  73.2      4.16
# 14584                      140.8                    94      4.03
#
#       deserci_n_transici_n deserci_n_primaria deserci_n_secundaria  \
# 14565                  NaN              10.59                 7.28
# 14566                 6.68                5.2                  7.8
# 14567                 2.86               6.15                  4.1
# 14568                  NaN               3.17                 2.76
# 14569                 2.25                2.3                 3.55
# 14570                 9.27               7.36                 6.24
# 14571                 2.13                2.6                 3.53
# 14572                 5.41                6.5                 4.12
# 14573                 6.21                5.4                 5.28
# 14574                 6.96                2.9                 2.95
# 14575                 2.46               4.21                 6.03
# 14576                 1.43               0.49                 5.92
# 14577                 3.31               4.12                 6.44
# 14578                 4.63               8.33                 2.49
# 14579                 6.45               4.79                 5.22
# 14580                  6.6                6.1                13.17
# 14581                 3.06                4.3                 4.36
# 14582                 5.83               8.59                 9.49
# 14583                 2.39               3.23                 6.12
# 14584                  NaN                NaN                 8.46
#
#       deserci_n_media aprobaci_n aprobaci_n_transici_n aprobaci_n_primaria  \
# 14565            2.63      89.71                     0               88.51
# 14566            3.87      93.87                     0               94.77
# 14567            1.05      84.05                  0.63               82.74
# 14568             NaN      97.35                     0               96.83
# 14569            2.45      96.98                     0               97.58
# 14570            4.09         92                     0               90.72
# 14571            3.56      87.55                     0               89.85
# 14572            2.11      89.01                     0               86.38
# 14573            1.05       94.9                     0                94.6
# 14574            2.29       93.6                     0                  94
# 14575            5.87      94.13                     0               95.31
# 14576            4.63      88.02                     0               86.02
# 14577            4.37      89.91                     0               89.74
# 14578            3.81      92.16                     0               89.53
# 14579            8.64      91.85                     0               91.49
# 14580            2.44      86.27                     0               90.29
# 14581            1.68      95.46                     0               95.12
# 14582            9.74      91.25                     0               91.41
# 14583            3.21      86.86                  0.24               90.04
# 14584            8.04      92.39                     0               97.84
#
#       aprobaci_n_secundaria aprobaci_n_media reprobaci_n  \
# 14565                 92.72            97.37         0.5
# 14566                  92.2             94.5        0.15
# 14567                 82.09             89.2       10.95
# 14568                 97.24              100           0
# 14569                 96.34             96.2        0.26
# 14570                 93.76            95.32         1.1
# 14571                    84            83.43        9.44
# 14572                 93.24            83.16        5.79
# 14573                 94.72            98.42        0.04
# 14574                 93.31            92.79        3.23
# 14575                 91.99            92.06        1.06
# 14576                 88.39            91.67        9.79
# 14577                 88.09             91.5        5.34
# 14578                 96.52            95.76        1.58
# 14579                 92.85            89.09        2.83
# 14580                 77.32            90.24        5.59
# 14581                 95.61            95.63        0.58
# 14582                 90.51            90.26           0
# 14583                 79.42            89.34        8.99
# 14584                 87.15            83.93        3.58
#
#       reprobaci_n_transici_n reprobaci_n_primaria reprobaci_n_secundaria  \
# 14565                      0                  0.9                      0
# 14566                      0                 0.03                      0
# 14567                   0.63                11.11                  13.81
# 14568                      0                    0                      0
# 14569                      0                 0.12                   0.11
# 14570                      0                 1.92                      0
# 14571                      0                 7.55                  12.47
# 14572                      0                 7.11                   2.65
# 14573                      0                    0                      0
# 14574                      0                  3.1                   3.74
# 14575                      0                 0.47                   1.98
# 14576                      0                  NaN                   5.69
# 14577                      0                 6.14                   5.47
# 14578                      0                 2.14                      1
# 14579                      0                 3.73                   1.93
# 14580                      0                 3.61                    9.5
# 14581                      0                 0.58                   0.04
# 14582                      0                    0                      0
# 14583                   0.24                 6.73                  14.46
# 14584                      0                 2.16                   4.39
#
#       reprobaci_n_media repitencia repitencia_transici_n repitencia_primaria  \
# 14565                 0       0.91                     0                1.28
# 14566              1.63       4.13                     0                5.24
# 14567              9.76       0.08                     0                0.12
# 14568                 0       0.48                     0                0.72
# 14569              1.35       3.12                  0.41                2.39
# 14570              0.58        NaN                  0.66                 NaN
# 14571             13.01       1.02                     0                0.54
# 14572             14.74       4.21                     0                 4.3
# 14573              0.53        NaN                     0                 NaN
# 14574              4.91       2.25                  0.66                2.41
# 14575              2.07       1.86                  0.06                1.81
# 14576               3.7          0                     0                   0
# 14577              4.13       3.25                     0                2.36
# 14578              0.42       0.48                     0                0.69
# 14579              2.27       3.92                     0                5.16
# 14580              7.32       0.71                     0                 0.7
# 14581              2.69       5.41                  0.73                5.53
# 14582                 0        NaN                  0.83                 NaN
# 14583              7.45       0.42                     0                0.24
# 14584              8.04        0.6                     0                0.96
#
#       repitencia_secundaria repitencia_media tama_o_promedio_de_grupo  \
# 14565                  0.67                0                    16.28
# 14566                  3.54             2.77                    20.75
# 14567                     0                0                    26.89
# 14568                  0.17                0                    30.56
# 14569                  5.03             1.63                    28.52
# 14570                   NaN             5.85                    26.95
# 14571                  2.07             0.57                    29.49
# 14572                  6.18                0                    17.79
# 14573                   2.3             1.27                    31.07
# 14574                  2.85             0.73                    26.36
# 14575                  2.67             0.95                    26.21
# 14576                     0                0                     16.3
# 14577                  6.09             1.94                    23.04
# 14578                     0                0                    20.09
# 14579                  1.92             2.96                    20.29
# 14580                  1.08                0                    19.57
# 14581                   6.9             4.11                    24.43
# 14582                  9.93             4.47                    20.01
# 14583                  0.91                0                    25.05
# 14584                     0                0                    32.14
#
#       sedes_conectadas_a_internet
# 14565                       83.33
# 14566                       97.06
# 14567                        87.8
# 14568                        96.3
# 14569                        87.5
# 14570                         100
# 14571                          84
# 14572                         100
# 14573                       82.98
# 14574                       47.22
# 14575                       65.91
# 14576                       88.89
# 14577                       90.91
# 14578                       63.93
# 14579                       86.49
# 14580                         100
# 14581                       93.44
# 14582                       53.45
# 14583                       83.33
# 14584                       81.25

# %% [markdown]
# Vamos a crear una copia del conjunto de datos, para cambiar los índices

# %%
df_raw2 = df_raw.copy()

# %%
df_raw.shape # Lo mismo que dim de R
# Out:
# (14585, 41)

# %%
df_raw2['new_index'] = range(1,df_raw.shape[0]+1)

# %%
df_raw2.set_index('new_index',inplace=True)

# %%
df_raw2.head()
# Out:
#             a_o c_digo_municipio   municipio c_digo_departamento departamento  \
# new_index
# 1          2023            05004    Abriaquí                  05    Antioquia
# 2          2023            95025  El Retorno                  95     Guaviare
# 3          2023            95200  Miraflores                  95     Guaviare
# 4          2023            97001        Mitú                  97       Vaupés
# 5          2023            97161      Caruru                  97       Vaupés
#
#           c_digo_etc              etc poblaci_n_5_16 tasa_matriculaci_n_5_16  \
# new_index
# 1               3758  Antioquia (ETC)            503                   62.62
# 2               3830   Guaviare (ETC)           4438                   53.27
# 3               3830   Guaviare (ETC)           2014                   32.52
# 4               3831     Vaupés (ETC)          10986                   59.57
# 5               3831     Vaupés (ETC)           1228                    51.3
#
#           cobertura_neta cobertura_neta_transici_n cobertura_neta_primaria  \
# new_index
# 1                  62.62                     44.19                   63.33
# 2                  53.27                     33.91                   48.89
# 3                  32.52                     17.58                   25.33
# 4                  59.57                     42.76                   55.95
# 5                   51.3                     76.32                   52.29
#
#           cobertura_neta_secundaria cobertura_neta_media cobertura_bruta  \
# new_index
# 1                             51.53                40.23            66.8
# 2                              44.9                 21.3           62.98
# 3                             26.43                10.75           38.58
# 4                             43.51                17.06           70.65
# 5                             33.71                11.94           55.54
#
#           cobertura_bruta_transici_n cobertura_bruta_primaria  \
# new_index
# 1                              58.14                    72.86
# 2                               54.2                    65.19
# 3                              36.36                    37.28
# 4                               64.9                    76.96
# 5                              92.11                    65.21
#
#           cobertura_bruta_secundaria cobertura_bruta_media deserci_n  \
# new_index
# 1                              66.87                 56.32      1.19
# 2                               69.6                 48.54      5.56
# 3                               46.1                 26.16      7.85
# 4                              72.92                 53.12      3.95
# 5                              51.12                 27.36      8.36
#
#           deserci_n_transici_n deserci_n_primaria deserci_n_secundaria  \
# new_index
# 1                            0               1.31                    0
# 2                         6.95               4.99                 6.11
# 3                           15               8.43                 6.36
# 4                         2.27               1.84                 6.77
# 5                         4.29               3.05                15.72
#
#           deserci_n_media aprobaci_n aprobaci_n_transici_n  \
# new_index
# 1                    4.08      92.26                     0
# 2                    5.26      87.67                     0
# 3                    4.69      82.68                  3.33
# 4                    5.47      90.71                  0.57
# 5                   14.55       82.4                     0
#
#           aprobaci_n_primaria aprobaci_n_secundaria aprobaci_n_media  \
# new_index
# 1                       96.73                 83.49            93.88
# 2                        87.9                  84.5            92.98
# 3                       84.64                 79.51             87.5
# 4                       94.12                 84.91            89.93
# 5                       89.63                    69            78.18
#
#           reprobaci_n reprobaci_n_transici_n reprobaci_n_primaria  \
# new_index
# 1                6.55                      0                 1.96
# 2                6.78                      0                 7.11
# 3                9.47                   3.33                 6.93
# 4                5.34                   0.57                 4.04
# 5                9.24                      0                 7.32
#
#           reprobaci_n_secundaria reprobaci_n_media repitencia  \
# new_index
# 1                          16.51              2.04       9.52
# 2                           9.39              1.75       9.34
# 3                          14.13              7.81       8.65
# 4                           8.33               4.6      16.18
# 5                          15.28              7.27       9.24
#
#           repitencia_transici_n repitencia_primaria repitencia_secundaria  \
# new_index
# 1                             0               10.46                 13.76
# 2                          6.95               11.84                  8.48
# 3                          6.67                9.04                 10.25
# 4                          7.75               21.04                 13.84
# 5                          2.86                7.62                 14.85
#
#           repitencia_media tama_o_promedio_de_grupo  \
# new_index
# 1                     2.04                      NaN
# 2                     3.16                      NaN
# 3                     1.54                      NaN
# 4                     7.18                      NaN
# 5                     3.64                      NaN
#
#           sedes_conectadas_a_internet
# new_index
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# 5                                 NaN

# %% [markdown]
# Para evaluar si existen registros repetidos, usamos el método `drop_duplicates`

# %%
df_raw.drop_duplicates().shape
# Out:
# (14585, 41)

# %% [markdown]
# ## Conversión de variables, según su naturaleza

# %%
df_raw['tasa_matriculaci_n_5_16'] = df_raw['tasa_matriculaci_n_5_16'].astype(float)

# %%
df_raw['tasa_matriculaci_n_5_16'].describe()
# Out:
# count    14470.000000
# mean        84.971929
# std         18.589112
# min          0.000000
# 25%         74.850000
# 50%         85.330000
# 75%         95.380000
# max        279.030000
# Name: tasa_matriculaci_n_5_16, dtype: float64

# %% [markdown]
# Ahora, vamos a generar una estadística de resumen a nivel de departamentos

# %%
df_raw.groupby(['c_digo_departamento','departamento'])['tasa_matriculaci_n_5_16'].mean().reset_index()
# Out:
#    c_digo_departamento                                       departamento  \
# 0                    0                                           NACIONAL
# 1                   05                                          Antioquia
# 2                   08                                          Atlántico
# 3                   11                                        Bogotá D.C.
# 4                   11                                       Bogotá, D.C.
# 5                   13                                            Bolívar
# 6                   15                                             Boyacá
# 7                   17                                             Caldas
# 8                   18                                            Caquetá
# 9                   19                                              Cauca
# 10                  20                                              Cesar
# 11                  23                                            Córdoba
# 12                  25                                       Cundinamarca
# 13                  27                                              Chocó
# 14                  41                                              Huila
# 15                  44                                         La Guajira
# 16                  47                                          Magdalena
# 17                   5                                          Antioquia
# 18                  50                                               Meta
# 19                  52                                             Nariño
# 20                  54                                 Norte de Santander
# 21                  63                                            Quindio
# 22                  66                                          Risaralda
# 23                  68                                          Santander
# 24                  70                                              Sucre
# 25                  73                                             Tolima
# 26                  76                                    Valle del Cauca
# 27                   8                                          Atlántico
# 28                  81                                             Arauca
# 29                  85                                           Casanare
# 30                  86                                           Putumayo
# 31                  88  Archipiélago de San Andrés, Providencia y Sant...
# 32                  88  Archipiélago de San Andrés. Providencia y Sant...
# 33                  91                                           Amazonas
# 34                  94                                            Guainía
# 35                  95                                           Guaviare
# 36                  97                                             Vaupés
# 37                  99                                            Vichada
#
#     tasa_matriculaci_n_5_16
# 0                  0.922600
# 1                 84.215040
# 2                 83.640435
# 3                 96.410000
# 4                 86.860833
# 5                 86.463798
# 6                 82.983827
# 7                 82.187436
# 8                 75.105529
# 9                 79.346987
# 10                96.113944
# 11                88.003057
# 12                87.205280
# 13                80.573439
# 14                85.088420
# 15                80.790923
# 16                94.591410
# 17                88.194655
# 18                91.258147
# 19                75.909501
# 20                83.849499
# 21                93.880000
# 22                84.438242
# 23                87.187691
# 24                95.251538
# 25                87.923552
# 26                84.256264
# 27                89.949373
# 28                79.976484
# 29                89.254321
# 30                79.806647
# 31                80.197083
# 32                84.980000
# 33                57.911240
# 34                60.224216
# 35                56.902692
# 36                60.409855
# 37                79.675769

# %% [markdown]
# Como `NACIONAL` no es un departamento, procedemos a quitarlo.

# %%
df_raw[df_raw['departamento']!= 'NACIONAL'] # data.table de R
# Out:
#         a_o c_digo_municipio    municipio c_digo_departamento departamento  \
# 0      2023            05004     Abriaquí                  05    Antioquia
# 1      2023            95025   El Retorno                  95     Guaviare
# 2      2023            95200   Miraflores                  95     Guaviare
# 3      2023            97001         Mitú                  97       Vaupés
# 4      2023            97161       Caruru                  97       Vaupés
# ...     ...              ...          ...                 ...          ...
# 14580  2011             5036  Angelópolis                   5    Antioquia
# 14581  2011             5034        Andes                   5    Antioquia
# 14582  2011             5031       Amalfi                   5    Antioquia
# 14583  2011             5030        Amagá                   5    Antioquia
# 14584  2011             5021   Alejandría                   5    Antioquia
#
#       c_digo_etc              etc poblaci_n_5_16  tasa_matriculaci_n_5_16  \
# 0           3758  Antioquia (ETC)            503                    62.62
# 1           3830   Guaviare (ETC)           4438                    53.27
# 2           3830   Guaviare (ETC)           2014                    32.52
# 3           3831     Vaupés (ETC)          10986                    59.57
# 4           3831     Vaupés (ETC)           1228                    51.30
# ...          ...              ...            ...                      ...
# 14580       3758  Antioquia (ETC)           1707                    78.85
# 14581       3758  Antioquia (ETC)          10244                    84.45
# 14582       3758  Antioquia (ETC)           5552                    97.71
# 14583       3758  Antioquia (ETC)           6631                    78.65
# 14584       3758  Antioquia (ETC)            702                   118.52
#
#       cobertura_neta cobertura_neta_transici_n cobertura_neta_primaria  \
# 0              62.62                     44.19                   63.33
# 1              53.27                     33.91                   48.89
# 2              32.52                     17.58                   25.33
# 3              59.57                     42.76                   55.95
# 4               51.3                     76.32                   52.29
# ...              ...                       ...                     ...
# 14580           78.9                      56.2                    82.4
# 14581           84.5                      65.1                    83.7
# 14582           97.7                      61.7                   107.2
# 14583           78.7                      55.3                    76.3
# 14584          118.5                      82.7                   127.6
#
#       cobertura_neta_secundaria cobertura_neta_media cobertura_bruta  \
# 0                         51.53                40.23            66.8
# 1                          44.9                 21.3           62.98
# 2                         26.43                10.75           38.58
# 3                         43.51                17.06           70.65
# 4                         33.71                11.94           55.54
# ...                         ...                  ...             ...
# 14580                      59.9                 26.4            82.8
# 14581                        62                 32.2            91.7
# 14582                      65.1                 27.3           108.4
# 14583                      70.7                 38.9            87.7
# 14584                      90.2                 48.5           134.9
#
#       cobertura_bruta_transici_n cobertura_bruta_primaria  \
# 0                          58.14                    72.86
# 1                           54.2                    65.19
# 2                          36.36                    37.28
# 3                           64.9                    76.96
# 4                          92.11                    65.21
# ...                          ...                      ...
# 14580                       77.4                      105
# 14581                       81.1                    107.5
# 14582                       77.9                    146.8
# 14583                       74.3                     89.8
# 14584                       86.5                    159.8
#
#       cobertura_bruta_secundaria cobertura_bruta_media deserci_n  \
# 0                          66.87                 56.32      1.19
# 1                           69.6                 48.54      5.56
# 2                           46.1                 26.16      7.85
# 3                          72.92                 53.12      3.95
# 4                          51.12                 27.36      8.36
# ...                          ...                   ...       ...
# 14580                       80.4                  40.1      8.14
# 14581                       89.9                  61.4      3.96
# 14582                       97.3                  53.9      8.75
# 14583                       96.3                  73.2      4.16
# 14584                      140.8                    94      4.03
#
#       deserci_n_transici_n deserci_n_primaria deserci_n_secundaria  \
# 0                        0               1.31                    0
# 1                     6.95               4.99                 6.11
# 2                       15               8.43                 6.36
# 3                     2.27               1.84                 6.77
# 4                     4.29               3.05                15.72
# ...                    ...                ...                  ...
# 14580                  6.6                6.1                13.17
# 14581                 3.06                4.3                 4.36
# 14582                 5.83               8.59                 9.49
# 14583                 2.39               3.23                 6.12
# 14584                  NaN                NaN                 8.46
#
#       deserci_n_media aprobaci_n aprobaci_n_transici_n aprobaci_n_primaria  \
# 0                4.08      92.26                     0               96.73
# 1                5.26      87.67                     0                87.9
# 2                4.69      82.68                  3.33               84.64
# 3                5.47      90.71                  0.57               94.12
# 4               14.55       82.4                     0               89.63
# ...               ...        ...                   ...                 ...
# 14580            2.44      86.27                     0               90.29
# 14581            1.68      95.46                     0               95.12
# 14582            9.74      91.25                     0               91.41
# 14583            3.21      86.86                  0.24               90.04
# 14584            8.04      92.39                     0               97.84
#
#       aprobaci_n_secundaria aprobaci_n_media reprobaci_n  \
# 0                     83.49            93.88        6.55
# 1                      84.5            92.98        6.78
# 2                     79.51             87.5        9.47
# 3                     84.91            89.93        5.34
# 4                        69            78.18        9.24
# ...                     ...              ...         ...
# 14580                 77.32            90.24        5.59
# 14581                 95.61            95.63        0.58
# 14582                 90.51            90.26           0
# 14583                 79.42            89.34        8.99
# 14584                 87.15            83.93        3.58
#
#       reprobaci_n_transici_n reprobaci_n_primaria reprobaci_n_secundaria  \
# 0                          0                 1.96                  16.51
# 1                          0                 7.11                   9.39
# 2                       3.33                 6.93                  14.13
# 3                       0.57                 4.04                   8.33
# 4                          0                 7.32                  15.28
# ...                      ...                  ...                    ...
# 14580                      0                 3.61                    9.5
# 14581                      0                 0.58                   0.04
# 14582                      0                    0                      0
# 14583                   0.24                 6.73                  14.46
# 14584                      0                 2.16                   4.39
#
#       reprobaci_n_media repitencia repitencia_transici_n repitencia_primaria  \
# 0                  2.04       9.52                     0               10.46
# 1                  1.75       9.34                  6.95               11.84
# 2                  7.81       8.65                  6.67                9.04
# 3                   4.6      16.18                  7.75               21.04
# 4                  7.27       9.24                  2.86                7.62
# ...                 ...        ...                   ...                 ...
# 14580              7.32       0.71                     0                 0.7
# 14581              2.69       5.41                  0.73                5.53
# 14582                 0        NaN                  0.83                 NaN
# 14583              7.45       0.42                     0                0.24
# 14584              8.04        0.6                     0                0.96
#
#       repitencia_secundaria repitencia_media tama_o_promedio_de_grupo  \
# 0                     13.76             2.04                      NaN
# 1                      8.48             3.16                      NaN
# 2                     10.25             1.54                      NaN
# 3                     13.84             7.18                      NaN
# 4                     14.85             3.64                      NaN
# ...                     ...              ...                      ...
# 14580                  1.08                0                    19.57
# 14581                   6.9             4.11                    24.43
# 14582                  9.93             4.47                    20.01
# 14583                  0.91                0                    25.05
# 14584                     0                0                    32.14
#
#       sedes_conectadas_a_internet
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 14580                         100
# 14581                       93.44
# 14582                       53.45
# 14583                       83.33
# 14584                       81.25
#
# [14582 rows x 41 columns]

# %%
df_raw.query("departamento != 'NACIONAL'")
# Out:
#         a_o c_digo_municipio    municipio c_digo_departamento departamento  \
# 0      2023            05004     Abriaquí                  05    Antioquia
# 1      2023            95025   El Retorno                  95     Guaviare
# 2      2023            95200   Miraflores                  95     Guaviare
# 3      2023            97001         Mitú                  97       Vaupés
# 4      2023            97161       Caruru                  97       Vaupés
# ...     ...              ...          ...                 ...          ...
# 14580  2011             5036  Angelópolis                   5    Antioquia
# 14581  2011             5034        Andes                   5    Antioquia
# 14582  2011             5031       Amalfi                   5    Antioquia
# 14583  2011             5030        Amagá                   5    Antioquia
# 14584  2011             5021   Alejandría                   5    Antioquia
#
#       c_digo_etc              etc poblaci_n_5_16  tasa_matriculaci_n_5_16  \
# 0           3758  Antioquia (ETC)            503                    62.62
# 1           3830   Guaviare (ETC)           4438                    53.27
# 2           3830   Guaviare (ETC)           2014                    32.52
# 3           3831     Vaupés (ETC)          10986                    59.57
# 4           3831     Vaupés (ETC)           1228                    51.30
# ...          ...              ...            ...                      ...
# 14580       3758  Antioquia (ETC)           1707                    78.85
# 14581       3758  Antioquia (ETC)          10244                    84.45
# 14582       3758  Antioquia (ETC)           5552                    97.71
# 14583       3758  Antioquia (ETC)           6631                    78.65
# 14584       3758  Antioquia (ETC)            702                   118.52
#
#       cobertura_neta cobertura_neta_transici_n cobertura_neta_primaria  \
# 0              62.62                     44.19                   63.33
# 1              53.27                     33.91                   48.89
# 2              32.52                     17.58                   25.33
# 3              59.57                     42.76                   55.95
# 4               51.3                     76.32                   52.29
# ...              ...                       ...                     ...
# 14580           78.9                      56.2                    82.4
# 14581           84.5                      65.1                    83.7
# 14582           97.7                      61.7                   107.2
# 14583           78.7                      55.3                    76.3
# 14584          118.5                      82.7                   127.6
#
#       cobertura_neta_secundaria cobertura_neta_media cobertura_bruta  \
# 0                         51.53                40.23            66.8
# 1                          44.9                 21.3           62.98
# 2                         26.43                10.75           38.58
# 3                         43.51                17.06           70.65
# 4                         33.71                11.94           55.54
# ...                         ...                  ...             ...
# 14580                      59.9                 26.4            82.8
# 14581                        62                 32.2            91.7
# 14582                      65.1                 27.3           108.4
# 14583                      70.7                 38.9            87.7
# 14584                      90.2                 48.5           134.9
#
#       cobertura_bruta_transici_n cobertura_bruta_primaria  \
# 0                          58.14                    72.86
# 1                           54.2                    65.19
# 2                          36.36                    37.28
# 3                           64.9                    76.96
# 4                          92.11                    65.21
# ...                          ...                      ...
# 14580                       77.4                      105
# 14581                       81.1                    107.5
# 14582                       77.9                    146.8
# 14583                       74.3                     89.8
# 14584                       86.5                    159.8
#
#       cobertura_bruta_secundaria cobertura_bruta_media deserci_n  \
# 0                          66.87                 56.32      1.19
# 1                           69.6                 48.54      5.56
# 2                           46.1                 26.16      7.85
# 3                          72.92                 53.12      3.95
# 4                          51.12                 27.36      8.36
# ...                          ...                   ...       ...
# 14580                       80.4                  40.1      8.14
# 14581                       89.9                  61.4      3.96
# 14582                       97.3                  53.9      8.75
# 14583                       96.3                  73.2      4.16
# 14584                      140.8                    94      4.03
#
#       deserci_n_transici_n deserci_n_primaria deserci_n_secundaria  \
# 0                        0               1.31                    0
# 1                     6.95               4.99                 6.11
# 2                       15               8.43                 6.36
# 3                     2.27               1.84                 6.77
# 4                     4.29               3.05                15.72
# ...                    ...                ...                  ...
# 14580                  6.6                6.1                13.17
# 14581                 3.06                4.3                 4.36
# 14582                 5.83               8.59                 9.49
# 14583                 2.39               3.23                 6.12
# 14584                  NaN                NaN                 8.46
#
#       deserci_n_media aprobaci_n aprobaci_n_transici_n aprobaci_n_primaria  \
# 0                4.08      92.26                     0               96.73
# 1                5.26      87.67                     0                87.9
# 2                4.69      82.68                  3.33               84.64
# 3                5.47      90.71                  0.57               94.12
# 4               14.55       82.4                     0               89.63
# ...               ...        ...                   ...                 ...
# 14580            2.44      86.27                     0               90.29
# 14581            1.68      95.46                     0               95.12
# 14582            9.74      91.25                     0               91.41
# 14583            3.21      86.86                  0.24               90.04
# 14584            8.04      92.39                     0               97.84
#
#       aprobaci_n_secundaria aprobaci_n_media reprobaci_n  \
# 0                     83.49            93.88        6.55
# 1                      84.5            92.98        6.78
# 2                     79.51             87.5        9.47
# 3                     84.91            89.93        5.34
# 4                        69            78.18        9.24
# ...                     ...              ...         ...
# 14580                 77.32            90.24        5.59
# 14581                 95.61            95.63        0.58
# 14582                 90.51            90.26           0
# 14583                 79.42            89.34        8.99
# 14584                 87.15            83.93        3.58
#
#       reprobaci_n_transici_n reprobaci_n_primaria reprobaci_n_secundaria  \
# 0                          0                 1.96                  16.51
# 1                          0                 7.11                   9.39
# 2                       3.33                 6.93                  14.13
# 3                       0.57                 4.04                   8.33
# 4                          0                 7.32                  15.28
# ...                      ...                  ...                    ...
# 14580                      0                 3.61                    9.5
# 14581                      0                 0.58                   0.04
# 14582                      0                    0                      0
# 14583                   0.24                 6.73                  14.46
# 14584                      0                 2.16                   4.39
#
#       reprobaci_n_media repitencia repitencia_transici_n repitencia_primaria  \
# 0                  2.04       9.52                     0               10.46
# 1                  1.75       9.34                  6.95               11.84
# 2                  7.81       8.65                  6.67                9.04
# 3                   4.6      16.18                  7.75               21.04
# 4                  7.27       9.24                  2.86                7.62
# ...                 ...        ...                   ...                 ...
# 14580              7.32       0.71                     0                 0.7
# 14581              2.69       5.41                  0.73                5.53
# 14582                 0        NaN                  0.83                 NaN
# 14583              7.45       0.42                     0                0.24
# 14584              8.04        0.6                     0                0.96
#
#       repitencia_secundaria repitencia_media tama_o_promedio_de_grupo  \
# 0                     13.76             2.04                      NaN
# 1                      8.48             3.16                      NaN
# 2                     10.25             1.54                      NaN
# 3                     13.84             7.18                      NaN
# 4                     14.85             3.64                      NaN
# ...                     ...              ...                      ...
# 14580                  1.08                0                    19.57
# 14581                   6.9             4.11                    24.43
# 14582                  9.93             4.47                    20.01
# 14583                  0.91                0                    25.05
# 14584                     0                0                    32.14
#
#       sedes_conectadas_a_internet
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 14580                         100
# 14581                       93.44
# 14582                       53.45
# 14583                       83.33
# 14584                       81.25
#
# [14582 rows x 41 columns]

# %%
resumen_matriculados_v0=(
    df_raw
    .query("departamento != 'NACIONAL'")
    .groupby(['c_digo_departamento','departamento'])
    ['tasa_matriculaci_n_5_16']
    .mean()
    .reset_index()
)

# %%
len(resumen_matriculados_v0['c_digo_departamento'][0]) # Longitud de un string
# Out:
# 2

# %%
def ajuste_cod_depto(codigo):
    if len(codigo)==1:
        codigo = '0' + codigo
    return codigo

# %% [markdown]
# Vamos a aplicar esta función a todo el conjunto de datos

# %%
df_raw['c_digo_departamento'] = df_raw['c_digo_departamento'].apply(ajuste_cod_depto)

# %%
(
    df_raw
    .query("departamento != 'NACIONAL'")
    .groupby(['c_digo_departamento','departamento'])
    ['tasa_matriculaci_n_5_16']
    .mean()
    .reset_index()
)
# Out:
#    c_digo_departamento                                       departamento  \
# 0                   05                                          Antioquia
# 1                   08                                          Atlántico
# 2                   11                                        Bogotá D.C.
# 3                   11                                       Bogotá, D.C.
# 4                   13                                            Bolívar
# 5                   15                                             Boyacá
# 6                   17                                             Caldas
# 7                   18                                            Caquetá
# 8                   19                                              Cauca
# 9                   20                                              Cesar
# 10                  23                                            Córdoba
# 11                  25                                       Cundinamarca
# 12                  27                                              Chocó
# 13                  41                                              Huila
# 14                  44                                         La Guajira
# 15                  47                                          Magdalena
# 16                  50                                               Meta
# 17                  52                                             Nariño
# 18                  54                                 Norte de Santander
# 19                  63                                            Quindio
# 20                  66                                          Risaralda
# 21                  68                                          Santander
# 22                  70                                              Sucre
# 23                  73                                             Tolima
# 24                  76                                    Valle del Cauca
# 25                  81                                             Arauca
# 26                  85                                           Casanare
# 27                  86                                           Putumayo
# 28                  88  Archipiélago de San Andrés, Providencia y Sant...
# 29                  88  Archipiélago de San Andrés. Providencia y Sant...
# 30                  91                                           Amazonas
# 31                  94                                            Guainía
# 32                  95                                           Guaviare
# 33                  97                                             Vaupés
# 34                  99                                            Vichada
#
#     tasa_matriculaci_n_5_16
# 0                 87.887206
# 1                 89.455816
# 2                 96.410000
# 3                 86.860833
# 4                 86.463798
# 5                 82.983827
# 6                 82.187436
# 7                 75.105529
# 8                 79.346987
# 9                 96.113944
# 10                88.003057
# 11                87.205280
# 12                80.573439
# 13                85.088420
# 14                80.790923
# 15                94.591410
# 16                91.258147
# 17                75.909501
# 18                83.849499
# 19                93.880000
# 20                84.438242
# 21                87.187691
# 22                95.251538
# 23                87.923552
# 24                84.256264
# 25                79.976484
# 26                89.254321
# 27                79.806647
# 28                80.197083
# 29                84.980000
# 30                57.911240
# 31                60.224216
# 32                56.902692
# 33                60.409855
# 34                79.675769

# %%
tabla_deptos = (
    df_raw
    .query("departamento != 'NACIONAL'")
    [['c_digo_departamento','departamento']]
    .drop_duplicates()
    .groupby('c_digo_departamento')
    .sample(n=1, random_state=1)
    .reset_index()
    .drop(columns= 'index')
)

# %%
df_raw = (
    df_raw
    .query("departamento != 'NACIONAL'")
    .drop(columns = 'departamento')
    .merge(tabla_deptos, on = 'c_digo_departamento', how = 'left')
)

# %%
(
    df_raw
    .query("departamento != 'NACIONAL'")
    .groupby(['c_digo_departamento','departamento'])
    ['tasa_matriculaci_n_5_16']
    .mean()
    .reset_index()
)
# Out:
#    c_digo_departamento                                       departamento  \
# 0                   05                                          Antioquia
# 1                   08                                          Atlántico
# 2                   11                                       Bogotá, D.C.
# 3                   13                                            Bolívar
# 4                   15                                             Boyacá
# 5                   17                                             Caldas
# 6                   18                                            Caquetá
# 7                   19                                              Cauca
# 8                   20                                              Cesar
# 9                   23                                            Córdoba
# 10                  25                                       Cundinamarca
# 11                  27                                              Chocó
# 12                  41                                              Huila
# 13                  44                                         La Guajira
# 14                  47                                          Magdalena
# 15                  50                                               Meta
# 16                  52                                             Nariño
# 17                  54                                 Norte de Santander
# 18                  63                                            Quindio
# 19                  66                                          Risaralda
# 20                  68                                          Santander
# 21                  70                                              Sucre
# 22                  73                                             Tolima
# 23                  76                                    Valle del Cauca
# 24                  81                                             Arauca
# 25                  85                                           Casanare
# 26                  86                                           Putumayo
# 27                  88  Archipiélago de San Andrés, Providencia y Sant...
# 28                  91                                           Amazonas
# 29                  94                                            Guainía
# 30                  95                                           Guaviare
# 31                  97                                             Vaupés
# 32                  99                                            Vichada
#
#     tasa_matriculaci_n_5_16
# 0                 87.887206
# 1                 89.455816
# 2                 87.595385
# 3                 86.463798
# 4                 82.983827
# 5                 82.187436
# 6                 75.105529
# 7                 79.346987
# 8                 96.113944
# 9                 88.003057
# 10                87.205280
# 11                80.573439
# 12                85.088420
# 13                80.790923
# 14                94.591410
# 15                91.258147
# 16                75.909501
# 17                83.849499
# 18                93.880000
# 19                84.438242
# 20                87.187691
# 21                95.251538
# 22                87.923552
# 23                84.256264
# 24                79.976484
# 25                89.254321
# 26                79.806647
# 27                80.565000
# 28                57.911240
# 29                60.224216
# 30                56.902692
# 31                60.409855
# 32                79.675769

# %% [markdown]
# Con respecto a la población del municipio, qué porcentaje de escolaridad hay?

# %%
def longitud_cod_mpio(codigo):
    return len(codigo)

set(
    df_raw
    .query("departamento != 'NACIONAL'")
    .assign(len_codigo_mpio = lambda x: x['c_digo_municipio'].apply(longitud_cod_mpio)) # análogo a la función mutate de dplyr en R
    ['len_codigo_mpio']
    .astype(str)
)
# Out:
# {'4', '5'}

# %%
def ajuste_cod_mpio(codigo):
    if len(codigo)==4:
        codigo = '0' + codigo
    return codigo

# %%
df_raw['c_digo_municipio'] = df_raw['c_digo_municipio'].apply(ajuste_cod_mpio)

# %%
df_raw.head()
# Out:
#     a_o c_digo_municipio   municipio c_digo_departamento c_digo_etc  \
# 0  2023            05004    Abriaquí                  05       3758
# 1  2023            95025  El Retorno                  95       3830
# 2  2023            95200  Miraflores                  95       3830
# 3  2023            97001        Mitú                  97       3831
# 4  2023            97161      Caruru                  97       3831
#
#                etc poblaci_n_5_16  tasa_matriculaci_n_5_16 cobertura_neta  \
# 0  Antioquia (ETC)            503                    62.62          62.62
# 1   Guaviare (ETC)           4438                    53.27          53.27
# 2   Guaviare (ETC)           2014                    32.52          32.52
# 3     Vaupés (ETC)          10986                    59.57          59.57
# 4     Vaupés (ETC)           1228                    51.30           51.3
#
#   cobertura_neta_transici_n cobertura_neta_primaria cobertura_neta_secundaria  \
# 0                     44.19                   63.33                     51.53
# 1                     33.91                   48.89                      44.9
# 2                     17.58                   25.33                     26.43
# 3                     42.76                   55.95                     43.51
# 4                     76.32                   52.29                     33.71
#
#   cobertura_neta_media cobertura_bruta cobertura_bruta_transici_n  \
# 0                40.23            66.8                      58.14
# 1                 21.3           62.98                       54.2
# 2                10.75           38.58                      36.36
# 3                17.06           70.65                       64.9
# 4                11.94           55.54                      92.11
#
#   cobertura_bruta_primaria cobertura_bruta_secundaria cobertura_bruta_media  \
# 0                    72.86                      66.87                 56.32
# 1                    65.19                       69.6                 48.54
# 2                    37.28                       46.1                 26.16
# 3                    76.96                      72.92                 53.12
# 4                    65.21                      51.12                 27.36
#
#   deserci_n deserci_n_transici_n deserci_n_primaria deserci_n_secundaria  \
# 0      1.19                    0               1.31                    0
# 1      5.56                 6.95               4.99                 6.11
# 2      7.85                   15               8.43                 6.36
# 3      3.95                 2.27               1.84                 6.77
# 4      8.36                 4.29               3.05                15.72
#
#   deserci_n_media aprobaci_n aprobaci_n_transici_n aprobaci_n_primaria  \
# 0            4.08      92.26                     0               96.73
# 1            5.26      87.67                     0                87.9
# 2            4.69      82.68                  3.33               84.64
# 3            5.47      90.71                  0.57               94.12
# 4           14.55       82.4                     0               89.63
#
#   aprobaci_n_secundaria aprobaci_n_media reprobaci_n reprobaci_n_transici_n  \
# 0                 83.49            93.88        6.55                      0
# 1                  84.5            92.98        6.78                      0
# 2                 79.51             87.5        9.47                   3.33
# 3                 84.91            89.93        5.34                   0.57
# 4                    69            78.18        9.24                      0
#
#   reprobaci_n_primaria reprobaci_n_secundaria reprobaci_n_media repitencia  \
# 0                 1.96                  16.51              2.04       9.52
# 1                 7.11                   9.39              1.75       9.34
# 2                 6.93                  14.13              7.81       8.65
# 3                 4.04                   8.33               4.6      16.18
# 4                 7.32                  15.28              7.27       9.24
#
#   repitencia_transici_n repitencia_primaria repitencia_secundaria  \
# 0                     0               10.46                 13.76
# 1                  6.95               11.84                  8.48
# 2                  6.67                9.04                 10.25
# 3                  7.75               21.04                 13.84
# 4                  2.86                7.62                 14.85
#
#   repitencia_media tama_o_promedio_de_grupo sedes_conectadas_a_internet  \
# 0             2.04                      NaN                         NaN
# 1             3.16                      NaN                         NaN
# 2             1.54                      NaN                         NaN
# 3             7.18                      NaN                         NaN
# 4             3.64                      NaN                         NaN
#
#   departamento
# 0    Antioquia
# 1     Guaviare
# 2     Guaviare
# 3       Vaupés
# 4       Vaupés

# %%
df_raw.head()
# Out:
#     a_o c_digo_municipio   municipio c_digo_departamento c_digo_etc  \
# 0  2023            05004    Abriaquí                  05       3758
# 1  2023            95025  El Retorno                  95       3830
# 2  2023            95200  Miraflores                  95       3830
# 3  2023            97001        Mitú                  97       3831
# 4  2023            97161      Caruru                  97       3831
#
#                etc poblaci_n_5_16  tasa_matriculaci_n_5_16 cobertura_neta  \
# 0  Antioquia (ETC)            503                    62.62          62.62
# 1   Guaviare (ETC)           4438                    53.27          53.27
# 2   Guaviare (ETC)           2014                    32.52          32.52
# 3     Vaupés (ETC)          10986                    59.57          59.57
# 4     Vaupés (ETC)           1228                    51.30           51.3
#
#   cobertura_neta_transici_n cobertura_neta_primaria cobertura_neta_secundaria  \
# 0                     44.19                   63.33                     51.53
# 1                     33.91                   48.89                      44.9
# 2                     17.58                   25.33                     26.43
# 3                     42.76                   55.95                     43.51
# 4                     76.32                   52.29                     33.71
#
#   cobertura_neta_media cobertura_bruta cobertura_bruta_transici_n  \
# 0                40.23            66.8                      58.14
# 1                 21.3           62.98                       54.2
# 2                10.75           38.58                      36.36
# 3                17.06           70.65                       64.9
# 4                11.94           55.54                      92.11
#
#   cobertura_bruta_primaria cobertura_bruta_secundaria cobertura_bruta_media  \
# 0                    72.86                      66.87                 56.32
# 1                    65.19                       69.6                 48.54
# 2                    37.28                       46.1                 26.16
# 3                    76.96                      72.92                 53.12
# 4                    65.21                      51.12                 27.36
#
#   deserci_n deserci_n_transici_n deserci_n_primaria deserci_n_secundaria  \
# 0      1.19                    0               1.31                    0
# 1      5.56                 6.95               4.99                 6.11
# 2      7.85                   15               8.43                 6.36
# 3      3.95                 2.27               1.84                 6.77
# 4      8.36                 4.29               3.05                15.72
#
#   deserci_n_media aprobaci_n aprobaci_n_transici_n aprobaci_n_primaria  \
# 0            4.08      92.26                     0               96.73
# 1            5.26      87.67                     0                87.9
# 2            4.69      82.68                  3.33               84.64
# 3            5.47      90.71                  0.57               94.12
# 4           14.55       82.4                     0               89.63
#
#   aprobaci_n_secundaria aprobaci_n_media reprobaci_n reprobaci_n_transici_n  \
# 0                 83.49            93.88        6.55                      0
# 1                  84.5            92.98        6.78                      0
# 2                 79.51             87.5        9.47                   3.33
# 3                 84.91            89.93        5.34                   0.57
# 4                    69            78.18        9.24                      0
#
#   reprobaci_n_primaria reprobaci_n_secundaria reprobaci_n_media repitencia  \
# 0                 1.96                  16.51              2.04       9.52
# 1                 7.11                   9.39              1.75       9.34
# 2                 6.93                  14.13              7.81       8.65
# 3                 4.04                   8.33               4.6      16.18
# 4                 7.32                  15.28              7.27       9.24
#
#   repitencia_transici_n repitencia_primaria repitencia_secundaria  \
# 0                     0               10.46                 13.76
# 1                  6.95               11.84                  8.48
# 2                  6.67                9.04                 10.25
# 3                  7.75               21.04                 13.84
# 4                  2.86                7.62                 14.85
#
#   repitencia_media tama_o_promedio_de_grupo sedes_conectadas_a_internet  \
# 0             2.04                      NaN                         NaN
# 1             3.16                      NaN                         NaN
# 2             1.54                      NaN                         NaN
# 3             7.18                      NaN                         NaN
# 4             3.64                      NaN                         NaN
#
#   departamento
# 0    Antioquia
# 1     Guaviare
# 2     Guaviare
# 3       Vaupés
# 4       Vaupés

# %%
ajuste_cod_depto('11')
# Out:
# '11'

# %%
df_raw.columns.to_list()
# Out:
# ['a_o',
#  'c_digo_municipio',
#  'municipio',
#  'c_digo_departamento',
#  'c_digo_etc',
#  'etc',
#  'poblaci_n_5_16',
#  'tasa_matriculaci_n_5_16',
#  'cobertura_neta',
#  'cobertura_neta_transici_n',
#  'cobertura_neta_primaria',
#  'cobertura_neta_secundaria',
#  'cobertura_neta_media',
#  'cobertura_bruta',
#  'cobertura_bruta_transici_n',
#  'cobertura_bruta_primaria',
#  'cobertura_bruta_secundaria',
#  'cobertura_bruta_media',
#  'deserci_n',
#  'deserci_n_transici_n',
#  'deserci_n_primaria',
#  'deserci_n_secundaria',
#  'deserci_n_media',
#  'aprobaci_n',
#  'aprobaci_n_transici_n',
#  'aprobaci_n_primaria',
#  'aprobaci_n_secundaria',
#  'aprobaci_n_media',
#  'reprobaci_n',
#  'reprobaci_n_transici_n',
#  'reprobaci_n_primaria',
#  'reprobaci_n_secundaria',
#  'reprobaci_n_media',
#  'repitencia',
#  'repitencia_transici_n',
#  'repitencia_primaria',
#  'repitencia_secundaria',
#  'repitencia_media',
#  'tama_o_promedio_de_grupo',
#  'sedes_conectadas_a_internet',
#  'departamento']

# %% [markdown]
# ## Crear una bodega de datos
#
# En esta bodega de datos, la idea es "subir" ambos conjuntos de datos y procesarlos desde SQL en una consulta

# %%
conn = sqlite3.connect("Datos2.db")
cursor = conn.cursor()

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\kevin\miniconda3\envs\diplomado_env\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\kevin\miniconda3\envs\diplomado_env\lib\site-packages (from openpyxl) (2.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import openpyxl 
datos_2005_2019 = pd.read_excel("C:\DIPLOMADO\Datos\Info_2005_2019.xlsx")
datos_2020_2035 = pd.read_excel("C:\DIPLOMADO\Datos\Info_2020_2035.xlsx")

# %%
datos_2005_2019.to_sql("informacion_antes_pandemia",conn)
datos_2020_2035.to_sql("informacion_despues_pandemia",conn)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 datos_2005_2019.to_sql("informacion_antes_pandemia",conn)
#       2 datos_2020_2035.to_sql("informacion_despues_pandemia",conn)
#
# File c:\Users\kevin\miniconda3\envs\diplomado_env\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\kevin\miniconda3\envs\diplomado_env\Lib\site-packages\pandas\core\generic.py:3106, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2908 """
#    2909 Write records stored in a DataFrame to a SQL database.
#    2910
#    (...)   3102 [(1,), (None,), (2,)]
#    3103 """  # noqa: E501
#    3104 from pandas.io import sql
# -> 3106 return sql.to_sql(
#    3107     self,
#    3108     name,
#    3109     con,
#    3110     schema=schema,
#    3111     if_exists=if_exists,
#    3112     index=index,
#    3113     index_label=index_label,
#    3114     chunksize=chunksize,
#    3115     dtype=dtype,
#    3116     method=method,
#    3117 )
#
# File c:\Users\kevin\miniconda3\envs\diplomado_env\Lib\site-packages\pandas\io\sql.py:844, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     839     raise NotImplementedError(
#     840         "'frame' argument should be either a Series or a DataFrame"
#     841     )
#     843 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 844     return pandas_sql.to_sql(
#     845         frame,
#     846         name,
#     847         if_exists=if_exists,
#     848         index=index,
#     849         index_label=index_label,
#     850         schema=schema,
#     851         chunksize=chunksize,
#     852         dtype=dtype,
#     853         method=method,
#     854         engine=engine,
#     855         **engine_kwargs,
#     856     )
#
# File c:\Users\kevin\miniconda3\envs\diplomado_env\Lib\site-packages\pandas\io\sql.py:2840, in SQLiteDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    2829             raise ValueError(f"{col} ({my_type}) not a string")
#    2831 table = SQLiteTable(
#    2832     name,
#    2833     self,
#    (...)   2838     dtype=dtype,
#    2839 )
# -> 2840 table.create()
#    2841 return table.insert(chunksize, method)
#
# File c:\Users\kevin\miniconda3\envs\diplomado_env\Lib\site-packages\pandas\io\sql.py:988, in SQLTable.create(self)
#     986 if self.exists():
#     987     if self.if_exists == "fail":
# --> 988         raise ValueError(f"Table '{self.name}' already exists.")
#     989     if self.if_exists == "replace":
#     990         self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'informacion_antes_pandemia' already exists.

# %%
datos_2020_2035.head()
# Out:
#    DP      DPNOM  MPIO      DPMP   AÑO                    ÁREA GEOGRÁFICA  \
# 0   5  Antioquia  5001  Medellín  2020                 Cabecera Municipal
# 1   5  Antioquia  5001  Medellín  2020  Centros Poblados y Rural Disperso
# 2   5  Antioquia  5001  Medellín  2020                              Total
# 3   5  Antioquia  5001  Medellín  2021                 Cabecera Municipal
# 4   5  Antioquia  5001  Medellín  2021  Centros Poblados y Rural Disperso
#
#    Población
# 0    2476569
# 1      43023
# 2    2519592
# 3    2506656
# 4      42352

# %%
consulta = """
CREATE TABLE info_proyeccion_mpios
AS

SELECT 
CASE WHEN LENGTH(CAST(DP AS STRING)) = 1 THEN CONCAT('0',CAST(DP AS STRING))
ELSE CAST(DP AS STRING) END AS c_digo_departamento,
CASE WHEN LENGTH(CAST(MPIO AS STRING)) = 4 THEN CONCAT('0',CAST(MPIO AS STRING))
ELSE CAST(MPIO AS STRING) END AS c_digo_municipio,
AÑO AS a_o,
Población AS poblacion_total
FROM informacion_antes_pandemia
WHERE `ÁREA GEOGRÁFICA` = 'Total'

UNION ALL

SELECT 
CASE WHEN LENGTH(CAST(DP AS STRING)) = 1 THEN CONCAT('0',CAST(DP AS STRING))
ELSE CAST(DP AS STRING) END AS c_digo_departamento,
CASE WHEN LENGTH(CAST(MPIO AS STRING)) = 4 THEN CONCAT('0',CAST(MPIO AS STRING))
ELSE CAST(MPIO AS STRING) END AS c_digo_municipio,
AÑO AS a_o,
Población AS poblacion_total
FROM informacion_despues_pandemia
WHERE `ÁREA GEOGRÁFICA` = 'Total'

"""

conn.execute(consulta)

# %%
consulta = """
CREATE TABLE info_proyeccion_mpios_v2
AS

WITH Tabla_Antes AS (

SELECT 
CASE WHEN LENGTH(CAST(DP AS STRING)) = 1 THEN CONCAT('0',CAST(DP AS STRING))
ELSE CAST(DP AS STRING) END AS c_digo_departamento,
CASE WHEN LENGTH(CAST(MPIO AS STRING)) = 4 THEN CONCAT('0',CAST(MPIO AS STRING))
ELSE CAST(MPIO AS STRING) END AS c_digo_municipio,
AÑO AS a_o,
Población AS poblacion_total
FROM informacion_antes_pandemia
WHERE `ÁREA GEOGRÁFICA` = 'Total'
)

, Tabla_Despues AS (

SELECT 
CASE WHEN LENGTH(CAST(DP AS STRING)) = 1 THEN CONCAT('0',CAST(DP AS STRING))
ELSE CAST(DP AS STRING) END AS c_digo_departamento,
CASE WHEN LENGTH(CAST(MPIO AS STRING)) = 4 THEN CONCAT('0',CAST(MPIO AS STRING))
ELSE CAST(MPIO AS STRING) END AS c_digo_municipio,
AÑO AS a_o,
Población AS poblacion_total
FROM informacion_despues_pandemia
WHERE `ÁREA GEOGRÁFICA` = 'Total'
)

SELECT * FROM Tabla_Antes
UNION ALL
SELECT * FROM Tabla_Despues
"""

conn.execute(consulta)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[52], line 36
#       1 consulta = """
#       2 CREATE TABLE info_proyeccion_mpios_v2
#       3 AS
#    (...)     33 SELECT * FROM Tabla_Despues
#      34 """
# ---> 36 conn.execute(consulta)
#
# OperationalError: table info_proyeccion_mpios_v2 already exists

# %%
consulta2 = """
SELECT * FROM info_proyeccion_mpios
"""

info_proyecciones_dane = pd.read_sql_query(consulta2,conn)

# %%
info_proyecciones_dane.query("c_digo_departamento == '95'")
# Out:
# Empty DataFrame
# Columns: [c_digo_departamento, c_digo_municipio, a_o, poblacion_total]
# Index: []

# %%
(
    df_raw
    .assign(a_o = lambda x: x['a_o'].astype(int))
    .merge(info_proyecciones_dane.drop(columns = 'c_digo_departamento'), 
           on = ['c_digo_municipio','a_o'], how = 'left')
)
# Out:
#         a_o c_digo_municipio    municipio c_digo_departamento c_digo_etc  \
# 0      2023            05004     Abriaquí                  05       3758
# 1      2023            95025   El Retorno                  95       3830
# 2      2023            95200   Miraflores                  95       3830
# 3      2023            97001         Mitú                  97       3831
# 4      2023            97161       Caruru                  97       3831
# ...     ...              ...          ...                 ...        ...
# 14577  2011            05036  Angelópolis                  05       3758
# 14578  2011            05034        Andes                  05       3758
# 14579  2011            05031       Amalfi                  05       3758
# 14580  2011            05030        Amagá                  05       3758
# 14581  2011            05021   Alejandría                  05       3758
#
#                    etc poblaci_n_5_16  tasa_matriculaci_n_5_16 cobertura_neta  \
# 0      Antioquia (ETC)            503                    62.62          62.62
# 1       Guaviare (ETC)           4438                    53.27          53.27
# 2       Guaviare (ETC)           2014                    32.52          32.52
# 3         Vaupés (ETC)          10986                    59.57          59.57
# 4         Vaupés (ETC)           1228                    51.30           51.3
# ...                ...            ...                      ...            ...
# 14577  Antioquia (ETC)           1707                    78.85           78.9
# 14578  Antioquia (ETC)          10244                    84.45           84.5
# 14579  Antioquia (ETC)           5552                    97.71           97.7
# 14580  Antioquia (ETC)           6631                    78.65           78.7
# 14581  Antioquia (ETC)            702                   118.52          118.5
#
#       cobertura_neta_transici_n cobertura_neta_primaria  \
# 0                         44.19                   63.33
# 1                         33.91                   48.89
# 2                         17.58                   25.33
# 3                         42.76                   55.95
# 4                         76.32                   52.29
# ...                         ...                     ...
# 14577                      56.2                    82.4
# 14578                      65.1                    83.7
# 14579                      61.7                   107.2
# 14580                      55.3                    76.3
# 14581                      82.7                   127.6
#
#       cobertura_neta_secundaria cobertura_neta_media cobertura_bruta  \
# 0                         51.53                40.23            66.8
# 1                          44.9                 21.3           62.98
# 2                         26.43                10.75           38.58
# 3                         43.51                17.06           70.65
# 4                         33.71                11.94           55.54
# ...                         ...                  ...             ...
# 14577                      59.9                 26.4            82.8
# 14578                        62                 32.2            91.7
# 14579                      65.1                 27.3           108.4
# 14580                      70.7                 38.9            87.7
# 14581                      90.2                 48.5           134.9
#
#       cobertura_bruta_transici_n cobertura_bruta_primaria  \
# 0                          58.14                    72.86
# 1                           54.2                    65.19
# 2                          36.36                    37.28
# 3                           64.9                    76.96
# 4                          92.11                    65.21
# ...                          ...                      ...
# 14577                       77.4                      105
# 14578                       81.1                    107.5
# 14579                       77.9                    146.8
# 14580                       74.3                     89.8
# 14581                       86.5                    159.8
#
#       cobertura_bruta_secundaria cobertura_bruta_media deserci_n  \
# 0                          66.87                 56.32      1.19
# 1                           69.6                 48.54      5.56
# 2                           46.1                 26.16      7.85
# 3                          72.92                 53.12      3.95
# 4                          51.12                 27.36      8.36
# ...                          ...                   ...       ...
# 14577                       80.4                  40.1      8.14
# 14578                       89.9                  61.4      3.96
# 14579                       97.3                  53.9      8.75
# 14580                       96.3                  73.2      4.16
# 14581                      140.8                    94      4.03
#
#       deserci_n_transici_n deserci_n_primaria deserci_n_secundaria  \
# 0                        0               1.31                    0
# 1                     6.95               4.99                 6.11
# 2                       15               8.43                 6.36
# 3                     2.27               1.84                 6.77
# 4                     4.29               3.05                15.72
# ...                    ...                ...                  ...
# 14577                  6.6                6.1                13.17
# 14578                 3.06                4.3                 4.36
# 14579                 5.83               8.59                 9.49
# 14580                 2.39               3.23                 6.12
# 14581                  NaN                NaN                 8.46
#
#       deserci_n_media aprobaci_n aprobaci_n_transici_n aprobaci_n_primaria  \
# 0                4.08      92.26                     0               96.73
# 1                5.26      87.67                     0                87.9
# 2                4.69      82.68                  3.33               84.64
# 3                5.47      90.71                  0.57               94.12
# 4               14.55       82.4                     0               89.63
# ...               ...        ...                   ...                 ...
# 14577            2.44      86.27                     0               90.29
# 14578            1.68      95.46                     0               95.12
# 14579            9.74      91.25                     0               91.41
# 14580            3.21      86.86                  0.24               90.04
# 14581            8.04      92.39                     0               97.84
#
#       aprobaci_n_secundaria aprobaci_n_media reprobaci_n  \
# 0                     83.49            93.88        6.55
# 1                      84.5            92.98        6.78
# 2                     79.51             87.5        9.47
# 3                     84.91            89.93        5.34
# 4                        69            78.18        9.24
# ...                     ...              ...         ...
# 14577                 77.32            90.24        5.59
# 14578                 95.61            95.63        0.58
# 14579                 90.51            90.26           0
# 14580                 79.42            89.34        8.99
# 14581                 87.15            83.93        3.58
#
#       reprobaci_n_transici_n reprobaci_n_primaria reprobaci_n_secundaria  \
# 0                          0                 1.96                  16.51
# 1                          0                 7.11                   9.39
# 2                       3.33                 6.93                  14.13
# 3                       0.57                 4.04                   8.33
# 4                          0                 7.32                  15.28
# ...                      ...                  ...                    ...
# 14577                      0                 3.61                    9.5
# 14578                      0                 0.58                   0.04
# 14579                      0                    0                      0
# 14580                   0.24                 6.73                  14.46
# 14581                      0                 2.16                   4.39
#
#       reprobaci_n_media repitencia repitencia_transici_n repitencia_primaria  \
# 0                  2.04       9.52                     0               10.46
# 1                  1.75       9.34                  6.95               11.84
# 2                  7.81       8.65                  6.67                9.04
# 3                   4.6      16.18                  7.75               21.04
# 4                  7.27       9.24                  2.86                7.62
# ...                 ...        ...                   ...                 ...
# 14577              7.32       0.71                     0                 0.7
# 14578              2.69       5.41                  0.73                5.53
# 14579                 0        NaN                  0.83                 NaN
# 14580              7.45       0.42                     0                0.24
# 14581              8.04        0.6                     0                0.96
#
#       repitencia_secundaria repitencia_media tama_o_promedio_de_grupo  \
# 0                     13.76             2.04                      NaN
# 1                      8.48             3.16                      NaN
# 2                     10.25             1.54                      NaN
# 3                     13.84             7.18                      NaN
# 4                     14.85             3.64                      NaN
# ...                     ...              ...                      ...
# 14577                  1.08                0                    19.57
# 14578                   6.9             4.11                    24.43
# 14579                  9.93             4.47                    20.01
# 14580                  0.91                0                    25.05
# 14581                     0                0                    32.14
#
#       sedes_conectadas_a_internet departamento  poblacion_total
# 0                             NaN    Antioquia           2841.0
# 1                             NaN     Guaviare              NaN
# 2                             NaN     Guaviare              NaN
# 3                             NaN       Vaupés              NaN
# 4                             NaN       Vaupés              NaN
# ...                           ...          ...              ...
# 14577                         100    Antioquia           5801.0
# 14578                       93.44    Antioquia          42173.0
# 14579                       53.45    Antioquia          24156.0
# 14580                       83.33    Antioquia          28354.0
# 14581                       81.25    Antioquia           4678.0
#
# [14582 rows x 42 columns]

# %%
set(df_raw.query('c_digo_departamento == "95"')['municipio'])
# Out:
# {'Calamar', 'El Retorno', 'Miraflores', 'San José del Guaviare'}

# %%
info_proyecciones_dane.query('c_digo_departamento == "95"')
# Out:
# Empty DataFrame
# Columns: [c_digo_departamento, c_digo_municipio, a_o, poblacion_total]
# Index: []

# %%
consulta4 = """
ALTER TABLE info_proyeccion_mpios_v2
AS

WITH Tabla_Antes AS (

SELECT 
CASE WHEN LENGTH(CAST(DP AS STRING)) = 1 THEN CONCAT('0',CAST(DP AS STRING))
ELSE CAST(DP AS STRING) END AS c_digo_departamento,
CASE WHEN LENGTH(CAST(MPIO AS STRING)) = 4 THEN CONCAT('0',CAST(MPIO AS STRING))
ELSE CAST(MPIO AS STRING) END AS c_digo_municipio,
AÑO AS a_o,
Población AS poblacion_total
FROM informacion_antes_pandemia
WHERE `ÁREA GEOGRÁFICA` = 'Total'
)

, Tabla_Despues AS (

SELECT 
CASE WHEN LENGTH(CAST(DP AS STRING)) = 1 THEN CONCAT('0',CAST(DP AS STRING))
ELSE CAST(DP AS STRING) END AS c_digo_departamento,
CASE WHEN LENGTH(CAST(MPIO AS STRING)) = 4 THEN CONCAT('0',CAST(MPIO AS STRING))
ELSE CAST(MPIO AS STRING) END AS c_digo_municipio,
AÑO AS a_o,
Población AS poblacion_total
FROM informacion_despues_pandemia
WHERE `ÁREA GEOGRÁFICA` = 'Total'
)

SELECT * FROM Tabla_Antes
UNION ALL
SELECT * FROM Tabla_Despues
"""

conn.execute(consulta)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[59], line 36
#       1 consulta4 = """
#       2 ALTER TABLE info_proyeccion_mpios_v2
#       3 AS
#    (...)     33 SELECT * FROM Tabla_Despues
#      34 """
# ---> 36 conn.execute(consulta)
#
# OperationalError: table info_proyeccion_mpios_v2 already exists

# %%
consulta3 = """
SELECT
CASE WHEN LENGTH(CAST(DP AS STRING)) = 1 THEN CONCAT('0',CAST(DP AS STRING))
ELSE CAST(DP AS STRING) END AS c_digo_departamento,
CASE WHEN LENGTH(CAST(MPIO AS STRING)) = 4 THEN CONCAT('0',CAST(MPIO AS STRING))
ELSE CAST(MPIO AS STRING) END AS c_digo_municipio,
AÑO AS a_o,
Población AS poblacion_total
FROM informacion_despues_pandemia
WHERE DP = 95 
AND `ÁREA GEOGRÁFICA` = 'Total'
"""

pd.read_sql_query(consulta3, conn)
# Out:
#     c_digo_departamento  c_digo_municipio   a_o  poblacion_total
# 0                    95             95001  2020            56294
# 1                    95             95001  2021            57717
# 2                    95             95001  2022            59555
# 3                    95             95001  2023            61403
# 4                    95             95001  2024            63208
# ..                  ...               ...   ...              ...
# 59                   95             95200  2031             9643
# 60                   95             95200  2032             9833
# 61                   95             95200  2033            10040
# 62                   95             95200  2034            10227
# 63                   95             95200  2035            10406
#
# [64 rows x 4 columns]

# %%
# ===================================================================
# PASO 3: EXTRACCIÓN BASE DIVIPOLA
# ===================================================================

print("📥 Extrayendo datos de DIVIPOLA desde su API...")

api_url_divipola = "https://www.datos.gov.co/resource/gdxc-w37w.json?$limit=2000"

try:
    response = requests.get(api_url_divipola)
    response.raise_for_status()
    data = response.json()
    df_divipola = pd.DataFrame(data)
    print(f"✅ ¡Base DIVIPOLA cargada! {len(df_divipola)} filas.")
except requests.exceptions.RequestException as e:
    print(f"❌ Error al extraer DIVIPOLA: {e}")
    df_divipola = pd.DataFrame()
except Exception as e:
    print(f"❌ Error inesperado: {e}")
    df_divipola = pd.DataFrame()
# Out:
# 📥 Extrayendo datos de DIVIPOLA desde su API...
# ✅ ¡Base DIVIPOLA cargada! 1122 filas.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 1. Histograma de tasa de matriculación
plt.hist(df_raw["tasa_matriculaci_n_5_16"], bins=10, color='purple', edgecolor='black')
plt.title("Histograma: Tasa de Matriculación (5-16 años)")
plt.xlabel("Tasa de Matriculación")
plt.ylabel("Frecuencia")
plt.show()

# %%
# Asegurarse de que la columna es numérica
df_raw["aprobaci_n"] = pd.to_numeric(df_raw["aprobaci_n"], errors="coerce")

# Boxplot limpio
plt.figure(figsize=(6, 4))
sns.boxplot(data=df_raw, y="aprobaci_n", color="skyblue")
plt.title("Boxplot: Aprobación (%)")
plt.ylabel("Porcentaje")
plt.tight_layout()
plt.show()

# %%
# DIMENSIÓN MUNICIPIO (solo con df_divipola)
dim_municipio = df_divipola[[
    "cod_mpio", "nom_mpio", "cod_dpto", "dpto", "tipo_municipio", "longitud", "latitud"
]].drop_duplicates()

dim_municipio = dim_municipio.rename(columns={
    "cod_mpio": "id_municipio",
    "nom_mpio": "municipio",
    "cod_dpto": "id_departamento",
    "dpto": "departamento"
})

dim_municipio.head(15)
# Out:
#    id_municipio              municipio id_departamento departamento  \
# 0         05001               MEDELLÍN              05    ANTIOQUIA
# 1         05002              ABEJORRAL              05    ANTIOQUIA
# 2         05004               ABRIAQUÍ              05    ANTIOQUIA
# 3         05021             ALEJANDRÍA              05    ANTIOQUIA
# 4         05030                  AMAGÁ              05    ANTIOQUIA
# 5         05031                 AMALFI              05    ANTIOQUIA
# 6         05034                  ANDES              05    ANTIOQUIA
# 7         05036            ANGELÓPOLIS              05    ANTIOQUIA
# 8         05038              ANGOSTURA              05    ANTIOQUIA
# 9         05040                  ANORÍ              05    ANTIOQUIA
# 10        05042  SANTA FÉ DE ANTIOQUIA              05    ANTIOQUIA
# 11        05044                   ANZÁ              05    ANTIOQUIA
# 12        05045               APARTADÓ              05    ANTIOQUIA
# 13        05051              ARBOLETES              05    ANTIOQUIA
# 14        05055                ARGELIA              05    ANTIOQUIA
#
#    tipo_municipio    longitud   latitud
# 0       Municipio  -75,581775  6,246631
# 1       Municipio  -75,428739  5,789315
# 2       Municipio  -76,064304  6,632282
# 3       Municipio  -75,141346  6,376061
# 4       Municipio  -75,702188  6,038708
# 5       Municipio  -75,077501  6,909655
# 6       Municipio  -75,878828  5,657194
# 7       Municipio  -75,711389  6,109719
# 8       Municipio  -75,335116  6,885175
# 9       Municipio  -75,148355  7,074703
# 10      Municipio  -75,826648  6,556484
# 11      Municipio  -75,854442  6,302641
# 12      Municipio  -76,625279  7,882968
# 13      Municipio  -76,426708  8,849317
# 14      Municipio   -75,14107  5,731474

# %%
# DIMENSIÓN DEPARTAMENTO
dim_departamento = df_raw[[
    "c_digo_departamento", "departamento"
]].drop_duplicates().rename(columns={
    "c_digo_departamento": "id_departamento"
})

dim_departamento.head(15)
# Out:
#     id_departamento                                       departamento
# 0                05                                          Antioquia
# 1                95                                           Guaviare
# 3                97                                             Vaupés
# 9                99                                            Vichada
# 14               94                                            Guainía
# 21               91                                           Amazonas
# 32               88  Archipiélago de San Andrés, Providencia y Sant...
# 34               86                                           Putumayo
# 47               85                                           Casanare
# 66               81                                             Arauca
# 73               76                                    Valle del Cauca
# 115              73                                             Tolima
# 163              70                                              Sucre
# 189              68                                          Santander
# 276              66                                          Risaralda

# %%
# DIMENSIÓN TIEMPO
dim_tiempo = df_raw[["a_o"]].drop_duplicates().rename(columns={
    "a_o": "anio"
}).sort_values(by="anio")

dim_tiempo.head(15)
# Out:
#        anio
# 13460  2011
# 12338  2012
# 11216  2013
# 10094  2014
# 8972   2015
# 7850   2016
# 6728   2017
# 5606   2018
# 4484   2019
# 3363   2020
# 2242   2021
# 1121   2022
# 0      2023

# %%
# DIMENSIÓN ETC
dim_etc = df_raw[["c_digo_etc", "etc"]].drop_duplicates().rename(columns={
    "c_digo_etc": "id_etc"
})

dim_etc.head(15)
# Out:
#    id_etc                                                etc
# 0    3758                                    Antioquia (ETC)
# 1    3830                                     Guaviare (ETC)
# 3    3831                                       Vaupés (ETC)
# 9    3832                                      Vichada (ETC)
# 14   3829                                      Guainía (ETC)
# 21   3828                                     Amazonas (ETC)
# 32   3827  Archipiélago de San Andrés, Providencia y Sant...
# 34   3826                                     Putumayo (ETC)
# 47   3825                                     Casanare (ETC)
# 65   4841                                              Yopal
# 66   3824                                       Arauca (ETC)
# 73   3817                              Valle del Cauca (ETC)
# 74   4832                                              Yumbo
# 79   3823                                              Tuluá
# 88   3822                                            Palmira

# %%
df_raw.to_sql("raw_educacion", conn, if_exists="replace", index=False)
# Out:
#   Cell In[73], line 1
#     df_raw.to_sql("raw_educacion", conn, if_exists="replace", index=False)
#                                                              ^
# SyntaxError: invalid non-printable character U+00A0

# %%
conn.execute("DROP TABLE IF EXISTS dim_departamento;")

conn.execute("""
CREATE TABLE dim_departamento AS
SELECT DISTINCT
    c_digo_departamento AS id_departamento,
    departamento
FROM raw_educacion;
""")
dim_departamento
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[71], line 3
#       1 conn.execute("DROP TABLE IF EXISTS dim_departamento;")
# ----> 3 conn.execute("""
#       4 CREATE TABLE dim_departamento AS
#       5 SELECT DISTINCT
#       6     c_digo_departamento AS id_departamento,
#       7     departamento
#       8 FROM raw_educacion;
#       9 """)
#      10 dim_departamento
#
# OperationalError: no such table: raw_educacion
